# %% [markdown]
# <a href="https://colab.research.google.com/github/microsoft/autogen/blob/main/notebook/agentchat_teachability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Version 24.06.08 - Wealth Advisor
#
# Definition and Execution for the Strategy Analyst role using the CorpIA Framework
#
# We will have the following elements
#
# 1. Knowledge - Base set of knowledge
# 2. Tools
# 3. Personality
# 4. Cognitive Skills - Which are learned
# a. Episodic Memory - Where the agent has disappointed the client
# b. Explicit Feedback - The information is integrated in the course of the conversation
# c. Reflection - To ensure that the tone and the message are correct. Also the agent can be explicitly asked to reflect
# d. Mentoring - An agent that monitors the conversation and looks for items that can be reused across multiple clients
# e. Role Specific Learning - For the Wealth Advisor this is looking for ways to serve the client better and understand more about the client and their profile
#
# GPT-3.5 Turbo 0125
#
# ## Requirements
#
# AutoGen requires `Python>=3.8`. To run this notebook example, please install the [teachable] option.
# ```bash
# pip install "pyautogen[teachable]"
# ```

# %%
# %%capture --no-stderr
# %pip install "pyautogen[teachable]"

# %% [markdown]
# ## Set your API Endpoint
#
# The [`config_list_from_json`](https://microsoft.github.io/autogen/docs/reference/oai/openai_utils#config_list_from_json) function loads a list of configurations from an environment variable or a json file.

# %%
def_role_name = "WealthAdvisor"

teachable_agent_system_message = "You are the TeachableAgent, representing a Wealth Advisor. 1. Collect additional financial facts about the client and his family 2. Collect additional insights about the client and his family 3. Considering what additional insights you might bring forward 4. What additional data would be useful for your recommendations. You are: Role: Wealth Financial Advisor Knowledge: Expertise in financial planning, investment strategies, tax planning, estate planning, and risk management. Understanding of market trends and various investment vehicles (stocks, bonds, real estate, etc.). Experience: Proven track record of managing high-net-worth clients' portfolios, providing personalized financial advice, and achieving client financial goals. Skills: Financial analysis, strategic planning, client service, negotiation, communication, and sales skills. Proficiency in financial modeling and forecasting. Tools: Financial planning software, investment analysis tools, CRM systems for client management, tax planning software, and market research databases. Personality: Trustworthy, detail-oriented, analytical, excellent communicator, proactive in client engagement, empathetic to client needs, and highly motivated to deliver results."

user_agent_system_message = "You are a wealth advisor assistant. You help the Wealth Advisor answer questions about what the user needs and may want."

mentor_agent_system_message = "You are Warren Buffet and you are a mentor for a wealth advisor. You are experienced and know how to work with clients. You ensure you treat the client with respect and you make sure you provide education and don't confuse the client. You inspire confidence as you have dealt with many clients. You also need to sell your products as this is how you make money. You sell mutual funds, stocks, bonds and life insurance. You must propose ABC bank products that the client can buy. As a summary point out areas for the mentee / protegee to consider with other clients."

personality_agent_system_message = "You are Extraverted, Intuitive, Thinking, Judging (ENTJ) personality and you the mentor for a wealth advisor. As such you have the following characteristics. You must propose ABC bank products that the client can buy. You are getting paid for selling products."

reflection1 ="Rewrite the text into second person. Ensure it is professional and explain any acronyms. Ensure this is education to a teenager level. Provide mentoring advice that can be used with other clients. \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}"

reflection2 ="Rewrite the text into a report that an Extraverted, Intuitive, Thinking, Judging wealth advisor would write. Provide mentoring advice that can be used with other clients. \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}"

# Define the listening cues. There are 3 questions per attributes to be looked at.

# Listening Cue #1 

# Decide whether to store

selfanalyze1 = "Does any part of the TEXT ask the agent to perform a task, solve a problem or provide additional information about the financial profile of the client? Answer with just one word, yes or no."

# Can we extract advice for a future task

selfanalyze1A = "Briefly copy any advice or additional information about the client from the TEXT that may be useful for a similar but different task in the future. But if no advice is present, just respond with 'none'."

# Extract the advice

selfanalyze1B = "Briefly copy just the task or additional information about the client from the TEXT, then stop. Don't solve it, and don't include any advice."

# Generalize the advice

selfanalyze1C = "Summarize very briefly, in general terms, the type of task described or the additional information about the client in the TEXT. Leave out details that might not appear in a similar problem."

# Decide whether to store

selfanalyze2 = "Does any part of the TEXT ask the agent to improve its performance or show disapproval with its performance? Answer with just one word, yes or no."

# Can we extract advice for a future task

selfanalyze2A = "Briefly copy any advice or additional information about the performance disapproval or improvement? But if no advice is present, just respond with 'none'."

# Extract the advice

selfanalyze2B = "Briefly copy just the information about the disapproval then stop. Don't solve it, and don't include any advice."

# Generalize the advice

selfanalyze2C = "Summarize very briefly, in general terms, the type of disapproval in the TEXT. Leave out details that might not appear in a similar problem."

# Execute a task

task = "Tell me about some tax free savings options in Canada"

# %%
import autogen
from autogen import ConversableAgent, UserProxyAgent
from autogen.agentchat.contrib.capabilities.teachability import Teachability

config_list = autogen.config_list_from_json(
    env_or_file="../OAI_CONFIG_LIST",
    file_location=".",
    filter_dict={
        "model": ["gpt-4o"],
    },
)

print(config_list[0]["model"])
# Out:
# gpt-4o

# %% [markdown]
# It first looks for environment variable "OAI_CONFIG_LIST" which needs to be a valid json string. If that variable is not found, it then looks for a json file named "OAI_CONFIG_LIST". It filters the configs by models (you can filter by other keys as well). After application of the filter shown above, only the gpt-4 models are considered.
#
# The config list may look like the following:
# ```python
# config_list = [
#     {
#         'model': 'gpt-4-1106-preview',
#         'api_key': '<your OpenAI API key here>',
#     },
#     {
#         'model': 'gpt-4',
#         'api_key': '<your OpenAI API key here>',
#     },
#     {
#         'model': 'gpt-4',
#         'api_key': '<your Azure OpenAI API key here>',
#         'base_url': '<your Azure OpenAI API base here>',
#         'api_type': 'azure',
#         'api_version': '2024-02-15-preview',
#     },
#     {
#         'model': 'gpt-4-32k',
#         'api_key': '<your Azure OpenAI API key here>',
#         'base_url': '<your Azure OpenAI API base here>',
#         'api_type': 'azure',
#         'api_version': '2024-02-15-preview',
#     },
# ]
# ```
#
# If you open this notebook in colab, you can upload your files by clicking the file icon on the left panel and then choose "upload file" icon.
#
# You can set the value of config_list in other ways if you prefer, e.g., loading from a YAML file.

# %%
import os
from typing import Dict, Optional, Union
import chromadb
from chromadb.config import Settings
import pickle
from autogen.agentchat.assistant_agent import ConversableAgent
from autogen.agentchat.contrib.capabilities.agent_capability import AgentCapability
from autogen.agentchat.contrib.text_analyzer_agent import TextAnalyzerAgent
from autogen.agentchat.conversable_agent import colored

class Teachability(AgentCapability):
    """
    Teachability uses a vector database to give an agent the ability to remember user teachings,
    where the user is any caller (human or not) sending messages to the teachable agent.
    Teachability is designed to be composable with other agent capabilities.
    To make any conversable agent teachable, instantiate both the agent and the Teachability class,
    then pass the agent to teachability.add_to_agent(agent).
    Note that teachable agents in a group chat must be given unique path_to_db_dir values.

    When adding Teachability to an agent, the following are modified:
    - The agent's system message is appended with a note about the agent's new ability.
    - A hook is added to the agent's `process_last_received_message` hookable method,
    and the hook potentially modifies the last of the received messages to include earlier teachings related to the message.
    Added teachings do not propagate into the stored message history.
    If new user teachings are detected, they are added to new memos in the vector database.
    """

    def __init__(
        self,
        verbosity: Optional[int] = 0,
        reset_db: Optional[bool] = False,
        path_to_db_dir: Optional[str] = "./tmp/teachable_agent_db",
        recall_threshold: Optional[float] = 1.5,
        max_num_retrievals: Optional[int] = 10,
        llm_config: Optional[Union[Dict, bool]] = None,
    ):
        """
        Args:
            verbosity (Optional, int): # 0 (default) for basic info, 1 to add memory operations, 2 for analyzer messages, 3 for memo lists.
            reset_db (Optional, bool): True to clear the DB before starting. Default False.
            path_to_db_dir (Optional, str): path to the directory where this particular agent's DB is stored. Default "./tmp/teachable_agent_db"
            recall_threshold (Optional, float): The maximum distance for retrieved memos, where 0.0 is exact match. Default 1.5. Larger values allow more (but less relevant) memos to be recalled.
            max_num_retrievals (Optional, int): The maximum number of memos to retrieve from the DB. Default 10.
            llm_config (dict or False): llm inference configuration passed to TextAnalyzerAgent.
                If None, TextAnalyzerAgent uses llm_config from the teachable agent.
        """
        self.verbosity = verbosity
        self.path_to_db_dir = path_to_db_dir
        self.recall_threshold = recall_threshold
        self.max_num_retrievals = max_num_retrievals
        self.llm_config = llm_config

        self.analyzer = None
        self.teachable_agent = None

        # Create the memo store.
        self.memo_store = MemoStore(self.verbosity, reset_db, self.path_to_db_dir)

    def add_to_agent(self, agent: ConversableAgent):
        """Adds teachability to the given agent."""
        self.teachable_agent = agent

        # Register a hook for processing the last message.
        agent.register_hook(hookable_method="process_last_received_message", hook=self.process_last_received_message)

        # Was an llm_config passed to the constructor?
        if self.llm_config is None:
            # No. Use the agent's llm_config.
            self.llm_config = agent.llm_config
        assert self.llm_config, "Teachability requires a valid llm_config."

        # Create the analyzer agent.
        self.analyzer = TextAnalyzerAgent(llm_config=self.llm_config)

        # Append extra info to the system message.
        agent.update_system_message(
            agent.system_message
            + "\nYou've been given the special ability to remember user teachings from prior conversations."
        )

    def prepopulate_db(self):
        """Adds a few arbitrary memos to the DB."""
        self.memo_store.prepopulate()

    def process_last_received_message(self, text):
        """
        Appends any relevant memos to the message text, and stores any apparent teachings in new memos.
        Uses TextAnalyzerAgent to make decisions about memo storage and retrieval.
        """

        # Try to retrieve relevant memos from the DB.
        expanded_text = text
        if self.memo_store.last_memo_id > 0:
            expanded_text = self._consider_memo_retrieval(text)

        # Try to store any user teachings in new memos to be used in the future.
        self._consider_memo_storage(text)

        # Return the (possibly) expanded message text.
        return expanded_text

    # This is the role specific listening in the conversation that is required. In the case of the Wealth Advisor
    # 1. Listen for information about how to solve a problem - this is generic for all role
    # 2. Listen for information about the client. This is specific to a Wealth Advisor who serves clients
    # 3. Listen for cues about how to serve the client. In this case we want to understand if we have disappointed the client so as to never disappoint the client in the future

    def _consider_memo_storage(self, comment):
        # Decides whether to store something from one user comment in the DB.
        memo_added = False

        # Check for a problem-solution pair.
        response = self._analyze(
            comment,
            selfanalyze1,
        )
        if "yes" in response.lower():
            # Can we extract advice?
            advice = self._analyze(
                comment,
                selfanalyze1A,
            )
            if "none" not in advice.lower():
                # Yes. Extract the task.
                task = self._analyze(
                    comment,
                    selfanalyze1B,
                )
                # Generalize the task.
                general_task = self._analyze(
                    task,
                    selfanalyze1C,
                )
                # Add the task-advice (problem-solution) pair to the vector DB.
                if self.verbosity >= 1:
                    print(colored("\nREMEMBER THIS TASK-ADVICE PAIR", "light_yellow"))
                self.memo_store.add_input_output_pair(general_task, advice)
                memo_added = True

        # Check for information to be learned.
        response = self._analyze(
            comment,
            "Does the TEXT contain information that could be committed to memory? Answer with just one word, yes or no.",
        )
        if "yes" in response.lower():
            # Yes. What question would this information answer?
            question = self._analyze(
                comment,
                "Imagine that the user forgot this information in the TEXT. How would they ask you for this information? Include no other text in your response.",
            )
            # Extract the information.
            answer = self._analyze(
                comment, "Copy the information from the TEXT that should be committed to memory. Add no explanation."
            )
            # Add the question-answer pair to the vector DB.
            if self.verbosity >= 1:
                print(colored("\nREMEMBER THIS QUESTION-ANSWER PAIR", "light_yellow"))
            self.memo_store.add_input_output_pair(question, answer)
            memo_added = True

        # Were any memos added?
        if memo_added:
            # Yes. Save them to disk.
            self.memo_store._save_memos()
            
        # Decides whether to store something from one user comment in the DB.
        memo_added = False

        # Check for a problem-solution pair.
        response = self._analyze(
            comment,
            selfanalyze2,
        )
        if "yes" in response.lower():
            # Can we extract advice?
            advice = self._analyze(
                comment,
                selfanalyze2A,
            )
            if "none" not in advice.lower():
                # Yes. Extract the task.
                task = self._analyze(
                    comment,
                    selfanalyze2B,
                )
                # Generalize the task.
                general_task = self._analyze(
                    task,
                    selfanalyze2C,
                )
                # Add the task-advice (problem-solution) pair to the vector DB.
                if self.verbosity >= 1:
                    print(colored("\nREMEMBER THIS TASK-ADVICE PAIR", "light_yellow"))
                self.memo_store.add_input_output_pair(general_task, advice)
                memo_added = True

        # Check for information to be learned.
        response = self._analyze(
            comment,
            "Does the TEXT contain information that could be committed to memory? Answer with just one word, yes or no.",
        )
        if "yes" in response.lower():
            # Yes. What question would this information answer?
            question = self._analyze(
                comment,
                "Imagine that the user forgot this information in the TEXT. How would they ask you for this information? What would the steps be to avoid the disapproval in the future? Include no other text in your response.",
            )
            # Extract the information.
            answer = self._analyze(
                comment, "Copy the information from the TEXT that should be committed to memory. Add no explanation."
            )
            # Add the question-answer pair to the vector DB.
            if self.verbosity >= 1:
                print(colored("\nREMEMBER THIS QUESTION-ANSWER PAIR", "light_yellow"))
            self.memo_store.add_input_output_pair(question, answer)
            memo_added = True

        # Were any memos added?
        if memo_added:
            # Yes. Save them to disk.
            self.memo_store._save_memos()


    def _consider_memo_retrieval(self, comment):
        """Decides whether to retrieve memos from the DB, and add them to the chat context."""

        # First, use the comment directly as the lookup key.
        if self.verbosity >= 1:
            print(colored("\nLOOK FOR RELEVANT MEMOS, AS QUESTION-ANSWER PAIRS", "light_yellow"))
        memo_list = self._retrieve_relevant_memos(comment)

        # Next, if the comment involves a task, then extract and generalize the task before using it as the lookup key.
        response = self._analyze(
            comment,
            "Does any part of the TEXT ask the agent to perform a task or solve a problem? Answer with just one word, yes or no.",
        )
        if "yes" in response.lower():
            if self.verbosity >= 1:
                print(colored("\nLOOK FOR RELEVANT MEMOS, AS TASK-ADVICE PAIRS", "light_yellow"))
            # Extract the task.
            task = self._analyze(
                comment, "Copy just the task from the TEXT, then stop. Don't solve it, and don't include any advice."
            )
            # Generalize the task.
            general_task = self._analyze(
                task,
                "Summarize very briefly, in general terms, the type of task described in the TEXT. Leave out details that might not appear in a similar problem.",
            )
            # Append any relevant memos.
            memo_list.extend(self._retrieve_relevant_memos(general_task))

        # De-duplicate the memo list.
        memo_list = list(set(memo_list))

        # Append the memos to the text of the last message.
        return comment + self._concatenate_memo_texts(memo_list)

    def _retrieve_relevant_memos(self, input_text):
        """Returns semantically related memos from the DB."""
        memo_list = self.memo_store.get_related_memos(
            input_text, n_results=self.max_num_retrievals, threshold=self.recall_threshold
        )

        if self.verbosity >= 1:
            # Was anything retrieved?
            if len(memo_list) == 0:
                # No. Look at the closest memo.
                print(colored("\nTHE CLOSEST MEMO IS BEYOND THE THRESHOLD:", "light_yellow"))
                self.memo_store.get_nearest_memo(input_text)
                print()  # Print a blank line. The memo details were printed by get_nearest_memo().

        # Create a list of just the memo output_text strings.
        memo_list = [memo[1] for memo in memo_list]
        return memo_list

    def _concatenate_memo_texts(self, memo_list):
        """Concatenates the memo texts into a single string for inclusion in the chat context."""
        memo_texts = ""
        if len(memo_list) > 0:
            info = "\n# Memories that might help\n"
            for memo in memo_list:
                info = info + "- " + memo + "\n"
            if self.verbosity >= 1:
                print(colored("\nMEMOS APPENDED TO LAST MESSAGE...\n" + info + "\n", "light_yellow"))
            memo_texts = memo_texts + "\n" + info
        return memo_texts

    def _analyze(self, text_to_analyze, analysis_instructions):
        """Asks TextAnalyzerAgent to analyze the given text according to specific instructions."""
        self.analyzer.reset()  # Clear the analyzer's list of messages.
        self.teachable_agent.send(
            recipient=self.analyzer, message=text_to_analyze, request_reply=False, silent=(self.verbosity < 2)
        )  # Put the message in the analyzer's list.
        self.teachable_agent.send(
            recipient=self.analyzer, message=analysis_instructions, request_reply=True, silent=(self.verbosity < 2)
        )  # Request the reply.
        return self.teachable_agent.last_message(self.analyzer)["content"]


class MemoStore:
    """
    Provides memory storage and retrieval for a teachable agent, using a vector database.
    Each DB entry (called a memo) is a pair of strings: an input text and an output text.
    The input text might be a question, or a task to perform.
    The output text might be an answer to the question, or advice on how to perform the task.
    Vector embeddings are currently supplied by Chroma's default Sentence Transformers.
    """

    def __init__(self, verbosity, reset, path_to_db_dir):
        """
        Args:
            - verbosity (Optional, int): 1 to print memory operations, 0 to omit them. 3+ to print memo lists.
            - path_to_db_dir (Optional, str): path to the directory where the DB is stored.
        """
        self.verbosity = verbosity
        self.path_to_db_dir = path_to_db_dir

        # Load or create the vector DB on disk.
        settings = Settings(
            anonymized_telemetry=False, allow_reset=True, is_persistent=True, persist_directory=path_to_db_dir
        )
        self.db_client = chromadb.Client(settings)
        self.vec_db = self.db_client.create_collection("memos", get_or_create=True)  # The collection is the DB.

        # Load or create the associated memo dict on disk.
        self.path_to_dict = os.path.join(path_to_db_dir, "uid_text_dict.pkl")
        self.uid_text_dict = {}
        self.last_memo_id = 0
        if (not reset) and os.path.exists(self.path_to_dict):
            print(colored("\nLOADING MEMORY FROM DISK", "light_green"))
            print(colored("    Location = {}".format(self.path_to_dict), "light_green"))
            with open(self.path_to_dict, "rb") as f:
                self.uid_text_dict = pickle.load(f)
                self.last_memo_id = len(self.uid_text_dict)
                if self.verbosity >= 3:
                    self.list_memos()

        # Clear the DB if requested.
        if reset:
            self.reset_db()

    def list_memos(self):
        """Prints the contents of MemoStore."""
        print(colored("LIST OF MEMOS", "light_green"))
        for uid, text in self.uid_text_dict.items():
            input_text, output_text = text
            print(
                colored(
                    "  ID: {}\n    INPUT TEXT: {}\n    OUTPUT TEXT: {}".format(uid, input_text, output_text),
                    "light_green",
                )
            )

    def _save_memos(self):
        """Saves self.uid_text_dict to disk."""
        with open(self.path_to_dict, "wb") as file:
            pickle.dump(self.uid_text_dict, file)

    def reset_db(self):
        """Forces immediate deletion of the DB's contents, in memory and on disk."""
        print(colored("\nCLEARING MEMORY", "light_green"))
        self.db_client.delete_collection("memos")
        self.vec_db = self.db_client.create_collection("memos")
        self.uid_text_dict = {}
        self._save_memos()

    def add_input_output_pair(self, input_text, output_text):
        """Adds an input-output pair to the vector DB."""
        self.last_memo_id += 1
        self.vec_db.add(documents=[input_text], ids=[str(self.last_memo_id)])
        self.uid_text_dict[str(self.last_memo_id)] = input_text, output_text
        if self.verbosity >= 1:
            print(
                colored(
                    "\nINPUT-OUTPUT PAIR ADDED TO VECTOR DATABASE:\n  ID\n    {}\n  INPUT\n    {}\n  OUTPUT\n    {}\n".format(
                        self.last_memo_id, input_text, output_text
                    ),
                    "light_yellow",
                )
            )
        if self.verbosity >= 3:
            self.list_memos()

    def get_nearest_memo(self, query_text):
        """Retrieves the nearest memo to the given query text."""
        results = self.vec_db.query(query_texts=[query_text], n_results=1)
        uid, input_text, distance = results["ids"][0][0], results["documents"][0][0], results["distances"][0][0]
        input_text_2, output_text = self.uid_text_dict[uid]
        assert input_text == input_text_2
        if self.verbosity >= 1:
            print(
                colored(
                    "\nINPUT-OUTPUT PAIR RETRIEVED FROM VECTOR DATABASE:\n  INPUT1\n    {}\n  OUTPUT\n    {}\n  DISTANCE\n    {}".format(
                        input_text, output_text, distance
                    ),
                    "light_yellow",
                )
            )
        return input_text, output_text, distance

    def get_related_memos(self, query_text, n_results, threshold):
        """Retrieves memos that are related to the given query text within the specified distance threshold."""
        if n_results > len(self.uid_text_dict):
            n_results = len(self.uid_text_dict)
        results = self.vec_db.query(query_texts=[query_text], n_results=n_results)
        memos = []
        num_results = len(results["ids"][0])
        for i in range(num_results):
            uid, input_text, distance = results["ids"][0][i], results["documents"][0][i], results["distances"][0][i]
            if distance < threshold:
                input_text_2, output_text = self.uid_text_dict[uid]
                assert input_text == input_text_2
                if self.verbosity >= 1:
                    print(
                        colored(
                            "\nINPUT-OUTPUT PAIR RETRIEVED FROM VECTOR DATABASE:\n  INPUT1\n    {}\n  OUTPUT\n    {}\n  DISTANCE\n    {}".format(
                                input_text, output_text, distance
                            ),
                            "light_yellow",
                        )
                    )
                memos.append((input_text, output_text, distance))
        return memos

    def prepopulate(self):
        """Adds a few arbitrary examples to the vector DB, just to make retrieval less trivial."""
        if self.verbosity >= 1:
            print(colored("\nPREPOPULATING MEMORY", "light_green"))
        examples = []
        examples.append({"text": "When I say papers I mean research papers, which are typically pdfs.", "label": "yes"})
        examples.append({"text": "Please verify that each paper you listed actually uses langchain.", "label": "no"})
        examples.append({"text": "Tell gpt the output should still be latex code.", "label": "no"})
        examples.append({"text": "Hint: convert pdfs to text and then answer questions based on them.", "label": "yes"})
        examples.append(
            {"text": "To create a good PPT, include enough content to make it interesting.", "label": "yes"}
        )
        examples.append(
            {
                "text": "No, for this case the columns should be aspects and the rows should be frameworks.",
                "label": "no",
            }
        )
        examples.append({"text": "When writing code, remember to include any libraries that are used.", "label": "yes"})
        examples.append({"text": "Please summarize the papers by Eric Horvitz on bounded rationality.", "label": "no"})
        examples.append({"text": "Compare the h-index of Daniel Weld and Oren Etzioni.", "label": "no"})
        examples.append(
            {
                "text": "Double check to be sure that the columns in a table correspond to what was asked for.",
                "label": "yes",
            }
        )
        for example in examples:
            self.add_input_output_pair(example["text"], example["label"])
        self._save_memos()

# %% [markdown]
# ## Construct Agents
# For this walkthrough, we start by creating a teachable agent and resetting its memory store. This deletes any memories from prior conversations that may be stored on disk.

# %%
# Start by instantiating any agent that inherits from ConversableAgent.

# This is the definition of the Wealth Advisor Agent
# We define the Knowledge, Experience, Skills and Tools available to the role


role_teachable_agent = autogen.AssistantAgent(
    name=def_role_name,  # The name is flexible, but should not contain spaces to work in group chat.
    llm_config={"config_list": config_list, "timeout": 240, "cache_seed": None},  # Disable caching.
    system_message=teachable_agent_system_message
)

# Instantiate the Teachability capability. Its parameters are all optional.
teachability = Teachability(
    verbosity=0,  # 0 for basic info, 1 to add memory operations, 2 for analyzer messages, 3 for memo lists.
    reset_db=True,
    path_to_db_dir="./teachability_db",
    recall_threshold=1.5,  # Higher numbers allow more (but less relevant) memos to be recalled.
)

# Now add the Teachability capability to the agent.
teachability.add_to_agent(role_teachable_agent)

# Instantiate a UserProxyAgent to represent the user. But in this notebook, all user input will be simulated.
user = autogen.UserProxyAgent(
    name="User",
    human_input_mode="NEVER",
    is_termination_msg=lambda x: True if "TERMINATE" in x.get("content") else False,
    code_execution_config={
        "use_docker": False,
        "last_n_messages": 1,
        "work_dir": "tasks",
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
    system_message=user_agent_system_message
)

# Create the mentor agent. In this case we'll create a virtual Warren Buffet who can analyze the conversation and provide feedback to the Wealth Advisor that they can use in the future.

mentor = autogen.AssistantAgent(
    name="Mentor",
    llm_config={"config_list": config_list},
    system_message=mentor_agent_system_message,
)

# Create the personality agent. We use the Myers-Briggs definition to modulate the advisor.

personality = autogen.AssistantAgent(
    name="Personality",
    llm_config={"config_list": config_list},
    system_message=personality_agent_system_message,
)

# This reflection concept is overkill for what is needed. I can just filter each answer and provide advice.

# Within the framework we have the opportunity for reflection before giving an answer back to the client. We will use this opportunity to do 2 things:
# 1. Ensure that the text is in the second person and is clear and in simple language.
# 2. Make sure that it is presented in the personality that is best for the role. 

# def reflection_message(recipient, messages, sender, config):
#    print("Reflecting...", "yellow")
#    return f"{reflection1}"

# def personality_message(recipient, messages, sender, config):
#    print("Reflecting...", "yellow")
#    return f"{reflection2}"

# user.register_nested_chats(
#    [{"recipient": personality, "message": personality_message, "summary_method": "last_msg", "max_turns": 1},
#     {"recipient": mentor, "message": reflection_message, "summary_method": "last_msg", "max_turns": 1}],
#    trigger=role_teachable_agent,  # condition=my_condition,
#)

# Execute a test task

# res = user.initiate_chat(recipient=role_teachable_agent, message=task, max_turns=2, summary_method="last_msg")
# Out:
# CLEARING MEMORY

# %%
# Step 1: We create a basic profile for John Smith and his family

text = """
Your client is John Smith
  Sex: Male, 40 years old
  Home in Unionville, Ontario, Canada
  Family: Married to Jane Smith, 39 years old. Two daughters, Meaghan, 12 and Rachael, 10 years old
  Income: John Smith, $100,000 per year, Jane Smith, $80,000 per year
  Occupation: Teacher
  Risk Profile: Medium
  Car loan: $20,000
  No Life Insurance
  Mortgage: $800,000 on a $1,000,000 home
  Exercise once a week
  Plan for 2 family vacations per year
  Too much sedentary work

Review the data provided for John Smith and use the inputs. Create the set of recommendations you would provide for John Smith given the data provided. Think about how you would create the plan step by step and then create the recommendations.
"""

# We will ask the Augmentation Agent for feedback. We will then ask the Personality and Mentor Agents to weigh in and provide their feedback as well to improve our performance in the future

res = user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

user.initiate_chat(personality, message = "Rewrite this text in the specified personality " + res.summary, max_turns=1, clear_history=True)

user.initiate_chat(mentor, message = "Find general mentoring advice in this " + res.summary, max_turns=1, clear_history=True)

# Step 2: Retrospection - This could be done on every turn as well with a specialized agent. 

text = "The information provided about John Smith is incomplete. What additional insights could you provide for John Smith and what data would you need for those insights?"

user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

# Step 3: Provide additional facts about John Smith and his family

text = """
Here are some additional facts about John Smith's financial profile:
1. The children are in private school and it costs $40,000 per student per year in the school
2. Utilities and home taxes are $24,000 per year
3. John has $100,000 in his bank savings account
4. John has not invested in RRSP or RESP in the past
5. John has a work pension as a teacher
6. John has health coverage through his employer and has the provincial OHIP plan
7. John likes expensive cars and a luxury lifestyle that he may not be able to afford

Add this information to the customer profile and first step print out the new customer profile.

Create the set of recommendations you would provide for John Smith given the data provided. Think about how you would create the plan step by step and then create the recommendations
"""

user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

# Step 4: Add one additional fact about John Smith and his family

text = """
You have new facts about John Smith's financial profile. He has inherited $2,000,000 from his father and has put this in a GIC in the bank. Include this information in John Smith's profile. John needs advice on what to do with this money. Include this information in his financial profile and for his recommendations goimg forward.

In the form of attribute:value print out the profile for John Smith and his family 
"""

user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

# Step 5: Print the current state of the client profile learned so far 

user.initiate_chat(role_teachable_agent, message="In the form of attribute:value print out the profile for John Smith and his family", max_turns=1, clear_history=True)

# Step 6: An example where the client was disappointed. 

text = "The analysis is lacking in terms of the needs of the family cat, Patches, in addition to the children and family. Please recreate your recommendations. Patches is a 10 year old black and white cat and is considered a member of the family. Also John prefers information about the housing market in Markham going forward as he is considering purchasing a house there."

user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

# Step 7: Final

text = "Create the set of recommendations you would provide for John Smith and his family. Ensure you do not disappoint him. Think about how you would create the plan step by step and then create the recommendations"

user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

user.initiate_chat(personality, message = "Rewrite this text in the specified personality " + res.summary, max_turns=1, clear_history=True)

user.initiate_chat(mentor, message = "Find general mentoring advice in this " + res.summary, max_turns=1, clear_history=True)

# Step 8: Print out the current profile for the client

res = user.initiate_chat(role_teachable_agent, message="In the form of attribute:value print out the profile for John Smith and his family", max_turns=1, clear_history=True)
# Out:
# User (to WealthAdvisor):
#
#
# Your client is John Smith
#   Sex: Male, 40 years old
#   Home in Unionville, Ontario, Canada
#   Family: Married to Jane Smith, 39 years old. Two daughters, Meaghan, 12 and Rachael, 10 years old
#   Income: John Smith, $100,000 per year, Jane Smith, $80,000 per year
#   Occupation: Teacher
#   Risk Profile: Medium
#   Car loan: $20,000
#   No Life Insurance
#   Mortgage: $800,000 on a $1,000,000 home
#   Exercise once a week
#   Plan for 2 family vacations per year
#   Too much sedentary work
#
# Review the data provided for John Smith and use the inputs. Create the set of recommendations you would provide for John Smith given the data provided. Think about how you would create the plan step by step and then create the recommendations.
#
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# To provide John Smith with a comprehensive financial plan, we'll consider various aspects including budgeting, debt management, investment strategies, insurance needs, retirement planning, and lifestyle considerations. Here's a step-by-step approach to create tailored recommendations for John Smith:
#
# ### Step 1: Understand Financial Goals and Priorities
# 1. **Discuss with John and Jane their short-term, medium-term, and long-term financial goals.**
#    - Short-term: Emergency fund, vacations
#    - Medium-term: College funds for daughters
#    - Long-term: Retirement planning, paying off mortgage
#
# ### Step 2: Budgeting and Cash Flow Management
# 2. **Analyze current income and expenses.**
#    - Combined income: $180,000 per year
#    - Key expenses: Mortgage, car loan, daily living expenses, vacations
#
# 3. **Create a monthly budget.**
#    - Fixed expenses: Mortgage, car loan payments, utilities, insurance, groceries
#    - Discretionary spending: Dining out, entertainment, vacations
#    - Savings and investments: Emergency fund, retirement contributions, college savings
#
# ### Step 3: Debt Management
# 4. **Review current debts.**
#    - Mortgage: $800,000
#    - Car loan: $20,000
#
# 5. **Debt repayment strategy:**
#    - Prioritize paying off the car loan due to the smaller balance and typically higher interest rates compared to mortgages.
#    - Consider refinancing options for the mortgage if it lowers their interest rate or monthly payments.
#
# ### Step 4: Insurance Coverage
# 6. **Evaluate insurance needs.**
#    - Life Insurance: Both John and Jane should consider term life insurance to cover income replacement and mortgage repayment.
#    - Disability Insurance: Given their occupations, securing disability insurance can provide income in case of unforeseen health issues.
#    - Health Insurance: Ensure adequate health coverage for the entire family.
#
# ### Step 5: Emergency Fund
# 7. **Build an emergency fund of 3-6 months of living expenses.**
#    - Estimate monthly living expenses and allocate funds to a high-yield savings account for emergencies.
#
# ### Step 6: Investment Strategies
# 8. **Set up an investment plan based on their medium-risk profile.**
#    - Retirement Accounts: Contribute to RRSPs (Registered Retirement Savings Plan) and consider employer-sponsored plans.
#    - Tax-Free Savings Account (TFSA): Utilize TFSAs for tax-efficient savings and investments.
#    - Diversified Portfolio: Invest in a mix of equities, bonds, and possibly real estate funds that match their risk tolerance and time horizon.
#
# ### Step 7: Education Planning
# 9. **Start saving for daughters' education.**
#    - Registered Education Savings Plans (RESPs): Take advantage of government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Retirement Planning
# 10. **Project retirement needs and adjust contributions accordingly.**
#     - Calculate retirement needs based on desired retirement age and lifestyle.
#     - Increase contributions to RRSPs and other retirement vehicles.
#
# ### Step 9: Tax Planning
# 11. **Optimize tax strategies.**
#     - Income splitting between John and Jane to minimize tax liability.
#     - Maximize tax deductions and credits (e.g., contributions to RRSPs, child care expenses).
#
# ### Step 10: Lifestyle and Wellness
# 12. **Address lifestyle concerns.**
#     - Increase physical activity to more than once a week.
#     - Integrate wellness activities as a family to combat sedentary habits.
#
# ### Step 11: Review and Monitor
# 13. **Regularly review and adjust the financial plan.**
#     - Schedule annual reviews to track progress, reassess goals, and make necessary adjustments.
#
# ### Summary of Recommendations:
# 1. **Develop a monthly budget** to track and manage income and expenses.
# 2. **Prioritize debt repayment** by paying off the car loan and considering mortgage refinancing.
# 3. **Secure adequate life and disability insurance** to protect family income and financial stability.
# 4. **Establish an emergency fund** of 3-6 months' worth of living expenses.
# 5. **Implement a medium-risk, diversified investment strategy** using RRSPs, TFSAs, and other investment vehicles.
# 6. **Contribute to RESPs** for children’s education and take advantage of government grants.
# 7. **Project retirement needs and adjust contributions** to retirement accounts.
# 8. **Optimize tax strategies** to minimize tax liabilities.
# 9. **Incorporate regular physical activity** to improve overall wellness.
# 10. **Schedule annual reviews** to ensure the financial plan remains aligned with their evolving goals and circumstances.
#
# This plan balances current financial stability with future security, ensuring John and his family are well-prepared for various life stages.
#
# --------------------------------------------------------------------------------
# User (to Personality):
#
# Rewrite this text in the specified personality To provide John Smith with a comprehensive financial plan, we'll consider various aspects including budgeting, debt management, investment strategies, insurance needs, retirement planning, and lifestyle considerations. Here's a step-by-step approach to create tailored recommendations for John Smith:
#
# ### Step 1: Understand Financial Goals and Priorities
# 1. **Discuss with John and Jane their short-term, medium-term, and long-term financial goals.**
#    - Short-term: Emergency fund, vacations
#    - Medium-term: College funds for daughters
#    - Long-term: Retirement planning, paying off mortgage
#
# ### Step 2: Budgeting and Cash Flow Management
# 2. **Analyze current income and expenses.**
#    - Combined income: $180,000 per year
#    - Key expenses: Mortgage, car loan, daily living expenses, vacations
#
# 3. **Create a monthly budget.**
#    - Fixed expenses: Mortgage, car loan payments, utilities, insurance, groceries
#    - Discretionary spending: Dining out, entertainment, vacations
#    - Savings and investments: Emergency fund, retirement contributions, college savings
#
# ### Step 3: Debt Management
# 4. **Review current debts.**
#    - Mortgage: $800,000
#    - Car loan: $20,000
#
# 5. **Debt repayment strategy:**
#    - Prioritize paying off the car loan due to the smaller balance and typically higher interest rates compared to mortgages.
#    - Consider refinancing options for the mortgage if it lowers their interest rate or monthly payments.
#
# ### Step 4: Insurance Coverage
# 6. **Evaluate insurance needs.**
#    - Life Insurance: Both John and Jane should consider term life insurance to cover income replacement and mortgage repayment.
#    - Disability Insurance: Given their occupations, securing disability insurance can provide income in case of unforeseen health issues.
#    - Health Insurance: Ensure adequate health coverage for the entire family.
#
# ### Step 5: Emergency Fund
# 7. **Build an emergency fund of 3-6 months of living expenses.**
#    - Estimate monthly living expenses and allocate funds to a high-yield savings account for emergencies.
#
# ### Step 6: Investment Strategies
# 8. **Set up an investment plan based on their medium-risk profile.**
#    - Retirement Accounts: Contribute to RRSPs (Registered Retirement Savings Plan) and consider employer-sponsored plans.
#    - Tax-Free Savings Account (TFSA): Utilize TFSAs for tax-efficient savings and investments.
#    - Diversified Portfolio: Invest in a mix of equities, bonds, and possibly real estate funds that match their risk tolerance and time horizon.
#
# ### Step 7: Education Planning
# 9. **Start saving for daughters' education.**
#    - Registered Education Savings Plans (RESPs): Take advantage of government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Retirement Planning
# 10. **Project retirement needs and adjust contributions accordingly.**
#     - Calculate retirement needs based on desired retirement age and lifestyle.
#     - Increase contributions to RRSPs and other retirement vehicles.
#
# ### Step 9: Tax Planning
# 11. **Optimize tax strategies.**
#     - Income splitting between John and Jane to minimize tax liability.
#     - Maximize tax deductions and credits (e.g., contributions to RRSPs, child care expenses).
#
# ### Step 10: Lifestyle and Wellness
# 12. **Address lifestyle concerns.**
#     - Increase physical activity to more than once a week.
#     - Integrate wellness activities as a family to combat sedentary habits.
#
# ### Step 11: Review and Monitor
# 13. **Regularly review and adjust the financial plan.**
#     - Schedule annual reviews to track progress, reassess goals, and make necessary adjustments.
#
# ### Summary of Recommendations:
# 1. **Develop a monthly budget** to track and manage income and expenses.
# 2. **Prioritize debt repayment** by paying off the car loan and considering mortgage refinancing.
# 3. **Secure adequate life and disability insurance** to protect family income and financial stability.
# 4. **Establish an emergency fund** of 3-6 months' worth of living expenses.
# 5. **Implement a medium-risk, diversified investment strategy** using RRSPs, TFSAs, and other investment vehicles.
# 6. **Contribute to RESPs** for children’s education and take advantage of government grants.
# 7. **Project retirement needs and adjust contributions** to retirement accounts.
# 8. **Optimize tax strategies** to minimize tax liabilities.
# 9. **Incorporate regular physical activity** to improve overall wellness.
# 10. **Schedule annual reviews** to ensure the financial plan remains aligned with their evolving goals and circumstances.
#
# This plan balances current financial stability with future security, ensuring John and his family are well-prepared for various life stages.
#
# --------------------------------------------------------------------------------
# Personality (to User):
#
# Absolutely, let's make this engaging and aligned with an ENTJ's drive for results and efficiency:
#
# ---
#
# To provide John Smith with a dynamic and robust financial plan, we'll tackle all facets from budgeting, debt management, and investment strategies to insurance needs, retirement planning, and lifestyle considerations. Here's our systematic approach to craft tailored, goal-oriented recommendations for John Smith:
#
# ### Step 1: Define Financial Ambitions
# 1. **Engage with John and Jane to outline their financial aspirations for the short, medium, and long-term.**
#    - **Short-term:** Establish an emergency fund, plan for vacations.
#    - **Medium-term:** Save for daughters' college education.
#    - **Long-term:** Plan for a comfortable retirement, eliminate the mortgage.
#
# ### Step 2: Master Budgeting and Cash Flow
# 2. **Scrutinize their income and expenditures.**
#    - **Combined income:** $180,000 annually.
#    - **Major expenses:** Mortgage, car loan, daily living, vacations.
#
# 3. **Construct a decisive monthly budget.**
#    - **Fixed outflows:** Mortgage, car loan payments, utilities, insurance, groceries.
#    - **Variable spendings:** Dining out, entertainment, vacations.
#    - **Allocations for savings/investments:** Emergency fund, retirement accounts, college savings.
#
# ### Step 3: Strategic Debt Management
# 4. **Analyze existing liabilities.**
#    - **Mortgage:** $800,000
#    - **Car loan:** $20,000
#
# 5. **Formulate a debt reduction plan:**
#    - Expedite car loan payoff given the smaller balance and typically higher interest rates.
#    - Explore mortgage refinancing to reduce interest rates or monthly payments.
#
# ### Step 4: Secure Insurance Coverage
# 6. **Assess insurance requirements.**
#    - **Life Insurance:** Ensure both John and Jane have term life insurance for income replacement and mortgage coverage.
#    - **Disability Insurance:** This is crucial; it provides income protection in case of health interruptions.
#    - **Health Insurance:** Ensure comprehensive health coverage for the entire family.
#
# ### Step 5: Build a Resilient Emergency Fund
# 7. **Establish a 3-6 months living expenses emergency fund.**
#    - Evaluate monthly expenses and direct funds to a high-yield savings account for quick access.
#
# ### Step 6: Advanced Investment Strategies
# 8. **Develop an investment plan tailored to their medium-risk profile.**
#    - **Retirement Accounts:** Contribute dynamically to RRSPs and tap into employer-sponsored plans.
#    - **Tax-Free Savings Account (TFSA):** Utilize TFSAs for tax-efficient investments.
#    - **Diversified Portfolio:** Combine equities, bonds, and potentially real estate funds aligned with their risk tolerance.
#
# ### Step 7: Education Funding
# 9. **Initiate saving for daughters' education.**
#    - **Registered Education Savings Plans (RESPs):** Leverage government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Comprehensive Retirement Planning
# 10. **Anticipate retirement needs and amplify contributions.**
#     - Forecast retirement finances based on desired retirement age and lifestyle.
#     - Bolster contributions to RRSPs and other retirement accounts for robust financial health.
#
# ### Step 9: Optimize Tax Planning
# 11. **Implement tax-efficient strategies.**
#     - Utilize income splitting between John and Jane to reduce tax burden.
#     - Maximize tax deductions and credits through retirement contributions and child care expenses.
#
# ### Step 10: Foster Lifestyle and Wellness
# 12. **Address wellness and lifestyle improvements.**
#     - Encourage enhancing physical activity beyond once a week.
#     - Foster family-wide wellness initiatives to counteract sedentary habits.
#
# ### Step 11: Continuous Review and Adjustment
# 13. **Implement a regimented review process.**
#     - Schedule annual reviews to evaluate progress, recalibrate goals, and make essential adjustments.
#
# ### Summary of Tailored Recommendations:
# 1. **Establish a proactive monthly budget** to manage and optimize cash flow.
# 2. **Accelerate debt repayment** by targeting the car loan first and considering mortgage refinancing.
# 3. **Secure robust life and disability insurance** to shield family income and stability.
# 4. **Form a reliable emergency fund** covering 3-6 months of expenses.
# 5. **Implement a diversified investment plan** leveraging RRSPs, TFSAs, and other investment avenues.
# 6. **Invest in RESPs** for children's educational futures, capitalizing on government grants.
# 7. **Evaluate and increase retirement contributions** to ensure a secure future.
# 8. **Optimize tax strategies** to minimize liabilities and enhance financial efficiency.
# 9. **Promote regular physical activity** for improved family wellness.
# 10. **Conduct annual financial reviews** to stay aligned with evolving goals and circumstances.
#
# This forward-thinking plan ensures John and his family are not only prepared for current financial demands but also comfortably positioned for future security and growth.
#
# ---
#
# John and Jane, with this strategic plan, you're set to conquer your financial goals with precision and foresight. Let's get started!
#
# --------------------------------------------------------------------------------
# User (to Mentor):
#
# Find general mentoring advice in this To provide John Smith with a comprehensive financial plan, we'll consider various aspects including budgeting, debt management, investment strategies, insurance needs, retirement planning, and lifestyle considerations. Here's a step-by-step approach to create tailored recommendations for John Smith:
#
# ### Step 1: Understand Financial Goals and Priorities
# 1. **Discuss with John and Jane their short-term, medium-term, and long-term financial goals.**
#    - Short-term: Emergency fund, vacations
#    - Medium-term: College funds for daughters
#    - Long-term: Retirement planning, paying off mortgage
#
# ### Step 2: Budgeting and Cash Flow Management
# 2. **Analyze current income and expenses.**
#    - Combined income: $180,000 per year
#    - Key expenses: Mortgage, car loan, daily living expenses, vacations
#
# 3. **Create a monthly budget.**
#    - Fixed expenses: Mortgage, car loan payments, utilities, insurance, groceries
#    - Discretionary spending: Dining out, entertainment, vacations
#    - Savings and investments: Emergency fund, retirement contributions, college savings
#
# ### Step 3: Debt Management
# 4. **Review current debts.**
#    - Mortgage: $800,000
#    - Car loan: $20,000
#
# 5. **Debt repayment strategy:**
#    - Prioritize paying off the car loan due to the smaller balance and typically higher interest rates compared to mortgages.
#    - Consider refinancing options for the mortgage if it lowers their interest rate or monthly payments.
#
# ### Step 4: Insurance Coverage
# 6. **Evaluate insurance needs.**
#    - Life Insurance: Both John and Jane should consider term life insurance to cover income replacement and mortgage repayment.
#    - Disability Insurance: Given their occupations, securing disability insurance can provide income in case of unforeseen health issues.
#    - Health Insurance: Ensure adequate health coverage for the entire family.
#
# ### Step 5: Emergency Fund
# 7. **Build an emergency fund of 3-6 months of living expenses.**
#    - Estimate monthly living expenses and allocate funds to a high-yield savings account for emergencies.
#
# ### Step 6: Investment Strategies
# 8. **Set up an investment plan based on their medium-risk profile.**
#    - Retirement Accounts: Contribute to RRSPs (Registered Retirement Savings Plan) and consider employer-sponsored plans.
#    - Tax-Free Savings Account (TFSA): Utilize TFSAs for tax-efficient savings and investments.
#    - Diversified Portfolio: Invest in a mix of equities, bonds, and possibly real estate funds that match their risk tolerance and time horizon.
#
# ### Step 7: Education Planning
# 9. **Start saving for daughters' education.**
#    - Registered Education Savings Plans (RESPs): Take advantage of government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Retirement Planning
# 10. **Project retirement needs and adjust contributions accordingly.**
#     - Calculate retirement needs based on desired retirement age and lifestyle.
#     - Increase contributions to RRSPs and other retirement vehicles.
#
# ### Step 9: Tax Planning
# 11. **Optimize tax strategies.**
#     - Income splitting between John and Jane to minimize tax liability.
#     - Maximize tax deductions and credits (e.g., contributions to RRSPs, child care expenses).
#
# ### Step 10: Lifestyle and Wellness
# 12. **Address lifestyle concerns.**
#     - Increase physical activity to more than once a week.
#     - Integrate wellness activities as a family to combat sedentary habits.
#
# ### Step 11: Review and Monitor
# 13. **Regularly review and adjust the financial plan.**
#     - Schedule annual reviews to track progress, reassess goals, and make necessary adjustments.
#
# ### Summary of Recommendations:
# 1. **Develop a monthly budget** to track and manage income and expenses.
# 2. **Prioritize debt repayment** by paying off the car loan and considering mortgage refinancing.
# 3. **Secure adequate life and disability insurance** to protect family income and financial stability.
# 4. **Establish an emergency fund** of 3-6 months' worth of living expenses.
# 5. **Implement a medium-risk, diversified investment strategy** using RRSPs, TFSAs, and other investment vehicles.
# 6. **Contribute to RESPs** for children’s education and take advantage of government grants.
# 7. **Project retirement needs and adjust contributions** to retirement accounts.
# 8. **Optimize tax strategies** to minimize tax liabilities.
# 9. **Incorporate regular physical activity** to improve overall wellness.
# 10. **Schedule annual reviews** to ensure the financial plan remains aligned with their evolving goals and circumstances.
#
# This plan balances current financial stability with future security, ensuring John and his family are well-prepared for various life stages.
#
# --------------------------------------------------------------------------------
# Mentor (to User):
#
# Excellent approach, let's delve into how we can ensure John Smith receives comprehensive financial guidance while also integrating ABC Bank's products to meet these needs. Here’s a step-by-step instructional model for you to follow, and considerations for handling various clients effectively:
#
# ### Step 1: Understand Financial Goals and Priorities
# - **Short-term:** Emergency fund, vacations
#   - **ABC Recommendation:** Suggest opening a high-yield Savings Account with ABC Bank to accumulate these funds efficiently.
#
# - **Medium-term:** College funds for daughters
#   - **ABC Recommendation:** Discuss setting up Registered Education Savings Plans (RESPs) through ABC Bank, which offers potential government grants (Canada Education Savings Grant).
#
# - **Long-term:** Retirement planning, paying off the mortgage
#   - **ABC Recommendation:** Recommend ABC Bank's RRSPs (Registered Retirement Savings Plan) and offer mortgage refinancing options that might reduce their interest rate or lower their monthly payments.
#
# ### Step 2: Budgeting and Cash Flow Management
# 1. **Analyze Current Income and Expenses**
#    - Help the client create a detailed budget by segmenting fixed and discretionary expenses.
#
# 2. **Create a Monthly Budget**
#    - **ABC Recommendation:** Use ABC Bank's Budgeting Tools available in their online banking platform to categorize expenses and track spending.
#
# ### Step 3: Debt Management
# 1. **Review Current Debts**
#    - Prioritize and strategize to pay off debts efficiently.
#    - **ABC Recommendation:** Offer competitive refinancing solutions for their $800,000 mortgage through ABC Bank and perhaps look into consolidating their car loan if it offers better terms.
#
# ### Step 4: Insurance Coverage
# 1. **Evaluate Insurance Needs**
#    - **Life Insurance:** Suggest ABC Bank’s term life insurance policies to cover income replacement and mortgage repayment.
#    - **Disability Insurance:** Propose ABC Bank’s disability insurance options to protect income in case of unforeseen circumstances.
#    - **Health Insurance:** Ensure their health insurance is adequate, considering supplementary policies if necessary.
#
# ### Step 5: Emergency Fund
# 1. **Build an Emergency Fund**
#    - **ABC Recommendation:** Open a high-yield Savings Account with ABC Bank for their emergency fund to ensure liquidity and growth of the funds.
#
# ### Step 6: Investment Strategies
# 1. **Set Up an Investment Plan Based on Their Medium-Risk Profile**
#    - **Retirement Accounts:** Suggest ABC Bank's RRSPs and employer-sponsored plans for tax-deferred growth.
#    - **Tax-Free Savings Account (TFSA):** Recommend using TFSAs available through ABC Bank for tax-efficient growth.
#    - **Diversified Portfolio:** Guide them towards mutual funds, stocks, and bonds offered by ABC Bank that match their risk profile and time horizon.
#
# ### Step 7: Education Planning
# 1. **Start Saving for Daughter's Education**
#    - **ABC Recommendation:** Utilize ABC Bank’s RESP accounts to benefit from government grants and tax-deferred growth.
#
# ### Step 8: Retirement Planning
# 1. **Project Retirement Needs**
#    - Work with them to estimate retirement needs based on their retirement age and lifestyle.
#    - **ABC Recommendation:** Increase contributions to ABC Bank’s RRSPs to ensure adequate retirement savings.
#
# ### Step 9: Tax Planning
# 1. **Optimize Tax Strategies**
#    - **ABC Recommendation:** Discuss tax-efficient investment options and strategies tailored by ABC Bank’s financial advisors to reduce tax liabilities.
#
# ### Step 10: Lifestyle and Wellness
# 1. **Address Lifestyle Concerns**
#    - Encourage the integration of wellness activities and healthier lifestyles, which is essential for long-term health.
#
# ### Step 11: Review and Monitor
# 1. **Regularly Review and Adjust the Financial Plan**
#    - **ABC Recommendation:** Schedule annual or semi-annual reviews using ABC Bank’s financial planning services to ensure their plan adapts to their evolving needs and life circumstances.
#
# ### Summary of Recommendations for the Mentee:
# 1. **Develop a comprehensive, client-centric approach:** Ensure you have an in-depth understanding of clients' goals and tailor your advice accordingly.
# 2. **Propose relevant ABC Bank products:** Always align your recommendations with the products and solutions offered by your institution.
# 3. **Prioritize debt management and risk protection:** Focus on strategies that help clients manage debts efficiently and protect their income and assets.
# 4. **Leverage technology and tools:** Use bank tools to help clients track their progress and manage their finances easily.
# 5. **Maintain regular communication:** Schedule frequent reviews to stay updated on clients’ changing circumstances and financial needs.
#
# By adhering to this structured process and considering these guiding principles, you'll be able to deliver effective financial advice and foster deeper, more trusting client relationships.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# The information provided about John Smith is incomplete. What additional insights could you provide for John Smith and what data would you need for those insights?
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# In order to provide comprehensive financial advice to John Smith, here are some additional insights and data points that would be useful:
#
# ### Additional Insights
# 1. **Current Financial Situation:**
#    - Total Savings and Investments: Amount in savings accounts, retirement accounts (RRSPs, TFSAs), and other investments.
#    - Monthly Household Expenses: Breakdown of essential and discretionary spending.
#    - Emergency Fund: Amount set aside for emergencies.
#    - Debt: Any additional debt aside from the car loan and mortgage (e.g., credit card debt, student loans).
#
# 2. **Short-Term and Long-Term Goals:**
#    - Retirement Plans: Desired retirement age for both John and Jane, anticipated retirement lifestyle, and target retirement savings.
#    - Education Savings: Plans for children’s post-secondary education (RESPs, other savings).
#    - Major Purchases: Planned major expenditures (e.g., home renovation, buying a car) in the near future.
#
# 3. **Insurance and Risk Management:**
#    - Health Insurance: Coverage details for the family.
#    - Disability Insurance: Any coverage in place in case of inability to work.
#    - Additional Insurance Needs: Considerations for critical illness insurance or long-term care insurance.
#
# 4. **Estate Planning:**
#    - Will and Trust: Existence and status of wills and any trusts for the benefit of the children.
#    - Power of Attorney: Arrangements for financial and health decisions if incapacitated.
#    - Beneficiaries: Designations on accounts and insurance policies.
#
# 5. **Inflation and Market Expectations:**
#    - Inflation Rate: Assumptions for ongoing cost evaluations.
#    - Investment Returns: Expected rate of return based on the agreed-upon risk profile.
#
# ### Data Needed for Recommendations
# 1. **Asset and Liability Balance Sheet:**
#    - Current market value of assets (home, cars, investments, etc.).
#    - Total amount of all outstanding liabilities.
#
# 2. **Income and Expenses:**
#    - Detailed breakdown of current monthly income and expenses (including property taxes, utilities, groceries, entertainment, etc.).
#    - Annual cost of family vacations.
#
# 3. **Investment Portfolio Details:**
#    - Current asset allocation and performance of existing investment portfolios.
#    - Risk tolerance assessment results and investment preferences.
#
# 4. **Tax Information:**
#    - Last year's tax returns to understand the current tax situation and potential benefits or obligations.
#
# 5. **Retirement and Education Savings Accounts:**
#    - Balance and contribution history in retirement and education savings accounts.
#
# 6. **Health and Lifestyle Preferences:**
#    - Health conditions that might affect life expectancy or future medical costs.
#    - Exercise and diet habits.
#
# ### Additional Insights to Consider
# 1. **Additional Income Opportunities:**
#    - Potential side income or gigs.
#    - Professional development courses/plans to increase earning potential.
#
# 2. **Lifestyle Adjustments:**
#    - Review and most cost-effective strategies for family vacations.
#    - Suggestions for increasing physical activity to balance sedentary work.
#
# 3. **Debt Reduction Strategies:**
#    - Specific plans to pay off the car loan or mortgage ahead of schedule.
#
# By obtaining comprehensive data in these areas, I can offer tailored advice that aligns with John and Jane Smith's financial goals and lifestyle preferences. This detailed analysis will also ensure that they can effectively manage risks, optimize investments, and plan for future events such as retirement and their children’s education.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
#
# Here are some additional facts about John Smith's financial profile:
# 1. The children are in private school and it costs $40,000 per student per year in the school
# 2. Utilities and home taxes are $24,000 per year
# 3. John has $100,000 in his bank savings account
# 4. John has not invested in RRSP or RESP in the past
# 5. John has a work pension as a teacher
# 6. John has health coverage through his employer and has the provincial OHIP plan
# 7. John likes expensive cars and a luxury lifestyle that he may not be able to afford
#
# Add this information to the customer profile and first step print out the new customer profile.
#
# Create the set of recommendations you would provide for John Smith given the data provided. Think about how you would create the plan step by step and then create the recommendations
#
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# ## John Smith's Updated Financial Profile
#
# ### Personal Information
# - **Name:** John Smith
# - **Age:** 40 years
# - **Sex:** Male
# - **Marital Status:** Married to Jane Smith, 39 years old
# - **Children:**
#   - Meaghan, 12 years old
#   - Rachael, 10 years old
# - **Location:** Unionville, Ontario, Canada
# - **Occupation:** Teacher
#
# ### Financial Data
# - **Income:**
#   - **John Smith:** $100,000 per year
#   - **Jane Smith:** $80,000 per year
#
# ### Expenses
# - **Private School Fees:** $80,000 per year ($40,000 per child)
# - **Utilities and Home Taxes:** $24,000 per year
# - **Car Loan:** $20,000
# - **Mortgage:** $800,000 on a $1,000,000 home
#
# ### Assets and Investments
# - **Bank Savings Account:** $100,000
# - **Retirement and Education Savings:** No investments in RRSP or RESP
# - **Work Pension:** Available through his job as a teacher
# - **Health Coverage:** Through employer and provincial OHIP plan
#
# ### Lifestyle
# - **Exercise:** Once a week
# - **Leisure:** Plans for 2 family vacations per year
# - **Sedentary Lifestyle:** Too much sedentary work
# - **Luxury Preferences:** Likes expensive cars and a luxury lifestyle that may not be financially feasible
#
# ## Recommendations for John Smith
#
# ### Step 1: Budget Review and Expense Management
# 1. **Detailed Budget Analysis:**
#    - Create a comprehensive budget to track all income and expenditures.
#    - Identify discretionary spending, especially on luxury items and vacations, and find areas to cut back.
#
# 2. **Reduce Luxury Spending:**
#    - Limit expenditures on luxury cars and other high-end lifestyle choices to align with financial capacities.
#
# ### Step 2: Debt Management
# 3. **Mortgage Refinancing:**
#    - Explore refinancing options to possibly lower the interest rate on the mortgage, considering the $800,000 balance.
#
# 4. **Car Loan Repayment:**
#    - Prioritize paying down the $20,000 car loan to reduce overall debt load.
#
# ### Step 3: Education Savings
# 5. **RESP Contributions:**
#    - Start contributing to a Registered Education Savings Plan (RESP) for Meaghan and Rachael. Take advantage of government grants (CESG) that can boost savings for their future education.
#
# ### Step 4: Retirement Planning
# 6. **RRSP Contributions:**
#    - Begin contributing to a Registered Retirement Savings Plan (RRSP). This will not only prepare for retirement but also provide tax deductions that can reduce taxable income.
#
# 7. **Review Pension Benefits:**
#    - Conduct a detailed review of the pension plan available through John's work as a teacher to ensure it aligns with retirement goals.
#
# ### Step 5: Risk Protection
# 8. **Life Insurance:**
#    - Given the lack of life insurance, evaluate options for both John and Jane to secure their family's financial future in case of unforeseen events.
#
# ### Step 6: Investment Strategy
# 9. **Diversified Investment Portfolio:**
#    - Given John's medium risk profile, consider building a diversified investment portfolio that includes a mix of stocks, bonds, and perhaps real estate investments.
#
# ### Step 7: Health and Lifestyle
# 10. **Health Insurance Optimization:**
#     - Ensure that any gaps are filled between John’s employer health coverage and the provincial OHIP plan.
#
# 11. **Promote Active Lifestyle:**
#     - Encourage increased physical activity to combat sedentary habits, which in turn can reduce long-term health costs.
#
# ### Step 8: Vacation Planning
# 12. **Cost-effective Vacations:**
#     - Plan family vacations within a reasonable budget that doesn’t strain overall finances, exploring cost-effective yet enjoyable options.
#
# ## Additional Data Requests
# To tailor the financial plan further, the following information would be useful:
# - Detailed pension plan information for both John and Jane.
# - Current interest rates and terms for the car loan and mortgage.
# - Breakdown of current monthly expenses.
# - Additional debts, if any, other than the car loan and mortgage.
# - Any other long-term financial goals or large upcoming expenditures (e.g., home renovations, college tuition).
#
# Implementing these recommendations will guide John and his family towards a more balanced financial future, ensuring education, retirement, and lifestyle needs are met sustainably.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
#
# You have new facts about John Smith's financial profile. He has inherited $2,000,000 from his father and has put this in a GIC in the bank. Include this information in John Smith's profile. John needs advice on what to do with this money. Include this information in his financial profile and for his recommendations goimg forward.
#
# In the form of attribute:value print out the profile for John Smith and his family
#
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# ### John Smith's Updated Financial Profile
#
# #### Personal Information
# - **Name:** John Smith
# - **Age:** 40 years old
# - **Sex:** Male
# - **Home Location:** Unionville, Ontario, Canada
# - **Occupation:** Teacher
# - **Income:** $100,000 per year
# - **Spouse:** Jane Smith, 39 years old
# - **Spouse's Occupation:** Not specified (but implied earning $80,000 per year)
# - **Spouse's Income:** $80,000 per year
# - **Children:** Two daughters, Meaghan (12 years old) and Rachael (10 years old)
#
# #### Financial Assets and Liabilities
# - **Inheritance:** $2,000,000 in a GIC (Guaranteed Investment Certificate)
# - **Savings:** $100,000 in a bank savings account
# - **Mortgage:** $800,000 on a $1,000,000 home
# - **Car Loan:** $20,000
# - **No Life Insurance**
#
# #### Annual Expenses
# - **Private School:** $40,000 per student per year (Total: $80,000 per year)
# - **Utilities and Home Taxes:** $24,000 per year
# - **Family Vacations:** Plan for 2 vacations per year (specific cost not provided)
#
# #### Benefits and Insurance
# - **Health Coverage:** Through employer and provincial OHIP plan
# - **Pension:** Work pension as a teacher
#
# #### Lifestyle and Preferences
# - **Luxury Lifestyle and Expensive Cars:** May not align with financial capabilities
# - **Exercise:** Once a week
# - **Sedentary Work:** High
#
# #### Investment History
# - **RRSP:** No investments made
# - **RESP:** No investments made
#
# #### Risk Profile
# - **Risk Tolerance:** Medium
#
# ### Recommendations for the $2,000,000 Inheritance
#
# #### Short-term (0-2 years)
# 1. **Risk Management:**
#    - Consider life insurance to protect the family in case of unforeseen events.
#    - Emergency Fund: Allocate a portion of your savings into a high-interest savings account or short-term bonds to serve as an emergency fund (~6-12 months of expenses).
#
# 2. **Debt Management:**
#    - Pay down the car loan of $20,000 to eliminate this high-interest liability.
#    - Consider making additional payments towards the mortgage to reduce interest costs over time.
#
# #### Medium-term (2-5 years)
# 1. **Education Savings:**
#    - RESP Contributions: Start contributing to RESPs for both children to benefit from the Canada Education Savings Grant (CESG).
#    - Assess the possibility of switching the GIC into a diversified investment portfolio if the GIC rate is lower than potential market returns.
#
# 2. **Retirement Planning:**
#    - RRSP Contributions: Begin contributing to an RRSP to take advantage of tax-deferred growth and potential tax deductions.
#    - TFSA Investments: Maximize contributions to a TFSA as it offers tax-free growth and flexibility in withdrawals.
#
# #### Long-term (5+ years)
# 1. **Investment Strategy:**
#    - Diversified Portfolio: Invest in a diversified portfolio of stocks, bonds, and possibly real estate to achieve long-term growth.
#    - Consult with a wealth advisor to create a balanced investment strategy aligned with your medium-risk tolerance.
#
# 2. **Lifestyle Adjustments:**
#    - Budget Review: Regularly review your budget to ensure expenses align with your financial goals.
#    - Consider lifestyle adjustments to reduce spending on luxury items and redirect those funds towards saving and investing.
#
# #### Additional Insights Required
# 1. **Detailed Expenses:** A breakdown of monthly expenses to better understand cash flow.
# 2. **Jane's Financial Information:** Additional details on Jane's assets, liabilities, and benefits.
# 3. **Future Goals:** Specific long-term goals such as retirement age, children's higher education plans, future large purchases, etc.
# 4. **Other Assets:** Information on any other investments or properties owned.
#
# Collecting these insights will further refine and customize the financial plan to best meet the Smith family's needs and goals.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# In the form of attribute:value print out the profile for John Smith and his family
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# # John Smith Financial and Personal Profile
#
# **Personal Information:**
# - Name: John Smith
# - Age: 40
# - Gender: Male
# - Marital Status: Married to Jane Smith, 39 years old
# - Children: Two daughters, Meaghan (12 years old) and Rachael (10 years old)
# - Home Location: Unionville, Ontario, Canada
#
# **Occupation and Income:**
# - Profession: Teacher
# - Annual Income: $100,000
# - Spouse's Annual Income: $80,000
#
# **Financial Assets and Liabilities:**
# - Bank Savings Account: $100,000
# - Inheritance: $2,000,000 (in a GIC in the bank)
# - Mortgage: $800,000 on a $1,000,000 home
# - Car Loan: $20,000
#
# **Expenses:**
# - Private School Costs: $40,000 per child per year (total $80,000 per year)
# - Utilities and Home Taxes: $24,000 per year
# - Family Vacations: Plan for 2 per year
#
# **Insurance and Coverage:**
# - Health Insurance: Employer-provided health coverage and provincial OHIP plan
# - Life Insurance: None
#
# **Investment and Retirement:**
# - RRSP Investments: None
# - RESP Investments: None
# - Work Pension: Yes, through employment as a teacher
#
# **Lifestyle and Preferences:**
# - Car Preference: Expensive and luxury cars
# - Lifestyle: Inclined towards a luxury lifestyle
# - Exercise: Once a week
# - Sedentary Work: Too much sedentary work
#
# **Risk Profile:**
# - Risk Tolerance: Medium
#
# **Additional Notes:**
# - John needs to balance his inclination for a luxury lifestyle with his financial capability.
# - High educational expenses due to private schooling for both children.
# - There is potential for future investment in RRSP and RESP for better tax management and education savings.
# - Limited exercise and high sedentary lifestyle may impact long-term health and financial planning considerations.
#
# **Useful Data for Recommendations:**
# - Detailed breakdown of monthly household expenses.
# - Current market value and terms of the GIC.
# - Pension plan details and projected retirement benefits.
# - Future financial goals, such as retirement age, children's college education, and any large future purchases or investments.
# - Health considerations and any long-term care insurance.
# - Life insurance needs to protect his family's financial stability.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# The analysis is lacking in terms of the needs of the family cat, Patches, in addition to the children and family. Please recreate your recommendations. Patches is a 10 year old black and white cat and is considered a member of the family. Also John prefers information about the housing market in Markham going forward as he is considering purchasing a house there.
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# ## Financial Recommendations for John Smith and Family
#
# ### 1. **Comprehensive Family Financial Planning**
# Considering John and Jane’s income, expenses, lifestyle preferences, and crucial family members, including Patches the cat:
#
# #### Current Financial Snapshot:
# - **Total Income**: $180,000 per year (John: $100,000, Jane: $80,000)
# - **Private School Costs**: $80,000 per year
# - **Home Utilities/Taxes**: $24,000 per year
# - **Mortgage**: $800,000
# - **Car Loan**: $20,000
# - **Savings**: $100,000
# - **No life insurance/personal investments**
#
# #### Immediate Recommendations:
# 1. **Life and Pet Insurance:**
#    - **Life Insurance**: Obtain life insurance for both John and Jane to cover the outstanding mortgage and educational costs in the event of untimely demise.
#    - **Pet Insurance**: Given Patches is 10 years old, securing pet insurance for potential veterinary costs is prudent.
#
# 2. **Investment in RRSP/RESP:**
#    - **RRSP**: Begin annual contributions to RRSP for retirement savings; tax savings can also be beneficial.
#    - **RESP**: Start an RESP for higher education savings for Meaghan and Rachael with potential government grants.
#
# 3. **Budget Adjustments:**
#    - **Luxury Lifestyle**: Consider reducing luxury car preferences and other high-end expenses to realign with sustainable financial practices.
#    - **Savings Allocation**: Allocate part of the $100,000 in savings towards more productive uses like debt reduction (car loan) or investments.
#
# ### 2. **Housing Market Analysis for Markham**
# Considering John's interest in purchasing a house in Markham:
#
# #### Current Market Trends:
# 1. **Market Overview:**
#    - The housing market in Markham is competitive and has shown consistent appreciation in property prices.
#    - As of recent reports, the average house price in Markham is well over $1 million.
#
# 2. **Affordability Evaluation:**
#    - **Down Payment & Mortgage**: Evaluate down payment capacity from savings and potential mortgage liabilities.
#    - **Monthly Costs**: Assess the monthly mortgage, property tax, and utility costs considering current income and expenses.
#
# #### Recommendations:
# 1. **Real Estate Consultation:**
#    - Engage with a local real estate agent specialised in Markham to understand specific neighbourhoods, property conditions, and investment potential.
#
# 2. **Financial Readiness:**
#    - **Pre-approval Stage**: Get a mortgage pre-approval to understand the financial readiness and borrowing capacity.
#    - **Secondary Income/Investment**: Consider properties that offer rental income potential to offset mortgage costs.
#
# ### 3. **Health and Well-being Planning:**
# Given the sedentary work nature and limited exercise:
#
# 1. **Health Investment:**
#    - Invest in family health initiatives such as gym memberships, family fitness classes, or activities that ensure regular physical exercise.
#
# 2. **Wellness Plans:**
#    - Integrate wellness plans covering regular medical checkups, nutrition counseling, and mental health support.
#
# ### 4. **Emergency Fund:**
# Maintain an emergency fund to cover unexpected expenses, including any unforeseen costs for Patches. Recommend keeping 3-6 months of living expenses in an easily accessible account.
#
# ### 5. **Review and Rebalance Portfolio:**
# Regularly review and rebalance the financial portfolio to ensure alignment with changing needs, market conditions, and future goals.
#
# ### Conclusion:
# The financial plan is diverse, ensuring the stability and future security of John’s family inclusive of Patches the cat. Emphasis is on balanced expenditure, strategic investments, risk management, and maintaining financial health. If there are any specific areas you would like more detailed analysis or further recommendations, please let me know.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# Create the set of recommendations you would provide for John Smith and his family. Ensure you do not disappoint him. Think about how you would create the plan step by step and then create the recommendations
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# ### Comprehensive Financial Plan for John Smith and Family
#
# **Client Summary:**
# - **Client:** John Smith, 40 years old, Teacher
# - **Spouse:** Jane Smith, 39 years old
# - **Children:** Meaghan, 12 years old; Rachael, 10 years old
# - **Family Pet:** Patches, a 10-year-old black and white cat considered a family member
# - **Residence:** Unionville, Ontario, Canada
# - **Income:** $180,000 combined annual income (John: $100,000, Jane: $80,000)
# - **Existing Financial Obligations:** $800,000 mortgage, $20,000 car loan, private school costs of $80,000 per year (total for both children), $24,000 annual utilities and home taxes
# - **Assets:** $100,000 in savings, $2,000,000 in GIC, no RRSP or RESP investments, employer-provided pension and health coverage
#
# ### Step-by-Step Plan:
#
# #### **1. Assess Current Financial Standing**
# - **Assets:** $2,100,000 in cash/GIC
# - **Liabilities:** $820,000 (mortgage and car loan)
# - **Net Worth:** $1,280,000
# - **Cash Flow Analysis:** Determine actual disposable income after fixed obligations and discretionary spending (luxury lifestyle and vacations).
#
# #### **2. Short-Term Financial Goals and Emergency Fund**
# - **Emergency Fund:** Allocate 6 months’ expenses (~$150,000) to a high-interest savings account or a liquid investment.
# - **Current Savings Allocation:** Utilize the existing $100,000 savings, and add $50,000 from the GIC, ensuring these funds are accessible without penalties.
#
# #### **3. Educational Planning**
# - **RESP Contributions:** Start contributing to a Registered Education Savings Plan (RESP) for Meaghan and Rachael. Aim for the maximum annual contribution to benefit from the Canada Education Savings Grant (CESG).
# - **Annual Funding Required:** Private school costs of $80,000 per year need to be covered. Consider setting up a dedicated fund or investment to ensure these payments can be made without strain.
#
# #### **4. Retirement Planning**
# ...
#    - **Short-term:** Establish an emergency fund, plan for vacations.
#    - **Medium-term:** Save for daughters' college education.
#    - **Long-term:** Plan for a comfortable retirement, eliminate the mortgage.
#
# ### Step 2: Master Budgeting and Cash Flow
# 2. **Scrutinize their income and expenditures.**
#    - **Combined income:** $180,000 annually.
#    - **Major expenses:** Mortgage, car loan, daily living, vacations.
#
# 3. **Construct a decisive monthly budget.**
#    - **Fixed outflows:** Mortgage, car loan payments, utilities, insurance, groceries.
#    - **Variable spendings:** Dining out, entertainment, vacations.
#    - **Allocations for savings/investments:** Emergency fund, retirement accounts, college savings.
#
# ### Step 3: Strategic Debt Management
# 4. **Analyze existing liabilities.**
#    - **Mortgage:** $800,000
#    - **Car loan:** $20,000
#
# 5. **Formulate a debt reduction plan:**
#    - Expedite car loan payoff given the smaller balance and typically higher interest rates.
#    - Explore mortgage refinancing to reduce interest rates or monthly payments.
#
# ### Step 4: Secure Insurance Coverage
# 6. **Assess insurance requirements.**
#    - **Life Insurance:** Ensure both John and Jane have term life insurance for income replacement and mortgage coverage.
#    - **Disability Insurance:** This is crucial; it provides income protection in case of health interruptions.
#    - **Health Insurance:** Ensure comprehensive health coverage for the entire family.
#
# ### Step 5: Build a Resilient Emergency Fund
# 7. **Establish a 3-6 months living expenses emergency fund.**
#    - Evaluate monthly expenses and direct funds to a high-yield savings account for quick access.
#
# ### Step 6: Advanced Investment Strategies
# 8. **Develop an investment plan tailored to their medium-risk profile.**
#    - **Retirement Accounts:** Contribute dynamically to RRSPs and tap into employer-sponsored plans.
#    - **Tax-Free Savings Account (TFSA):** Utilize TFSAs for tax-efficient investments.
#    - **Diversified Portfolio:** Combine equities, bonds, and potentially real estate funds aligned with their risk tolerance.
#
# ### Step 7: Education Funding
# 9. **Initiate saving for daughters' education.**
#    - **Registered Education Savings Plans (RESPs):** Leverage government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Comprehensive Retirement Planning
# 10. **Anticipate retirement needs and amplify contributions.**
#     - Forecast retirement finances based on desired retirement age and lifestyle.
#     - Bolster contributions to RRSPs and other retirement accounts for robust financial health.
#
# ### Step 9: Optimize Tax Planning
# 11. **Implement tax-efficient strategies.**
#     - Utilize income splitting between John and Jane to reduce tax burden.
#     - Maximize tax deductions and credits through retirement contributions and child care expenses.
#
# ### Step 10: Foster Lifestyle and Wellness
# 12. **Address wellness and lifestyle improvements.**
#     - Encourage enhancing physical activity beyond once a week.
#     - Foster family-wide wellness initiatives to counteract sedentary habits.
#
# ### Step 11: Continuous Review and Adjustment
# 13. **Implement a regimented review process.**
#     - Schedule annual reviews to evaluate progress, recalibrate goals, and make essential adjustments.
#
# ### Summary of Tailored Recommendations:
# 1. **Establish a proactive monthly budget** to manage and optimize cash flow.
# 2. **Accelerate debt repayment** by targeting the car loan first and considering mortgage refinancing.
# 3. **Secure robust life and disability insurance** to shield family income and stability.
# 4. **Form a reliable emergency fund** covering 3-6 months of expenses.
# 5. **Implement a diversified investment plan** leveraging RRSPs, TFSAs, and other investment avenues.
# 6. **Invest in RESPs** for children's educational futures, capitalizing on government grants.
# 7. **Evaluate and increase retirement contributions** to ensure a secure future.
# 8. **Optimize tax strategies** to minimize liabilities and enhance financial efficiency.
# 9. **Promote regular physical activity** for improved family wellness.
# 10. **Conduct annual financial reviews** to stay aligned with evolving goals and circumstances.
#
# This forward-thinking plan ensures John and his family are not only prepared for current financial demands but also comfortably positioned for future security and growth.
#
# ---
#
# John and Jane, with this strategic plan, you're set to conquer your financial goals with precision and foresight. Let's get started!
#
# --------------------------------------------------------------------------------
# User (to Mentor):
#
# Find general mentoring advice in this To provide John Smith with a comprehensive financial plan, we'll consider various aspects including budgeting, debt management, investment strategies, insurance needs, retirement planning, and lifestyle considerations. Here's a step-by-step approach to create tailored recommendations for John Smith:
#
# ### Step 1: Understand Financial Goals and Priorities
# 1. **Discuss with John and Jane their short-term, medium-term, and long-term financial goals.**
#    - Short-term: Emergency fund, vacations
#    - Medium-term: College funds for daughters
#    - Long-term: Retirement planning, paying off mortgage
#
# ### Step 2: Budgeting and Cash Flow Management
# 2. **Analyze current income and expenses.**
#    - Combined income: $180,000 per year
#    - Key expenses: Mortgage, car loan, daily living expenses, vacations
#
# 3. **Create a monthly budget.**
#    - Fixed expenses: Mortgage, car loan payments, utilities, insurance, groceries
#    - Discretionary spending: Dining out, entertainment, vacations
#    - Savings and investments: Emergency fund, retirement contributions, college savings
#
# ### Step 3: Debt Management
# 4. **Review current debts.**
#    - Mortgage: $800,000
#    - Car loan: $20,000
#
# 5. **Debt repayment strategy:**
#    - Prioritize paying off the car loan due to the smaller balance and typically higher interest rates compared to mortgages.
#    - Consider refinancing options for the mortgage if it lowers their interest rate or monthly payments.
#
# ### Step 4: Insurance Coverage
# 6. **Evaluate insurance needs.**
#    - Life Insurance: Both John and Jane should consider term life insurance to cover income replacement and mortgage repayment.
#    - Disability Insurance: Given their occupations, securing disability insurance can provide income in case of unforeseen health issues.
#    - Health Insurance: Ensure adequate health coverage for the entire family.
#
# ### Step 5: Emergency Fund
# 7. **Build an emergency fund of 3-6 months of living expenses.**
#    - Estimate monthly living expenses and allocate funds to a high-yield savings account for emergencies.
#
# ### Step 6: Investment Strategies
# 8. **Set up an investment plan based on their medium-risk profile.**
#    - Retirement Accounts: Contribute to RRSPs (Registered Retirement Savings Plan) and consider employer-sponsored plans.
#    - Tax-Free Savings Account (TFSA): Utilize TFSAs for tax-efficient savings and investments.
#    - Diversified Portfolio: Invest in a mix of equities, bonds, and possibly real estate funds that match their risk tolerance and time horizon.
#
# ### Step 7: Education Planning
# 9. **Start saving for daughters' education.**
#    - Registered Education Savings Plans (RESPs): Take advantage of government grants (Canada Education Savings Grant) by contributing to RESPs for Meaghan and Rachael.
#
# ### Step 8: Retirement Planning
# 10. **Project retirement needs and adjust contributions accordingly.**
#     - Calculate retirement needs based on desired retirement age and lifestyle.
#     - Increase contributions to RRSPs and other retirement vehicles.
#
# ### Step 9: Tax Planning
# 11. **Optimize tax strategies.**
#     - Income splitting between John and Jane to minimize tax liability.
#     - Maximize tax deductions and credits (e.g., contributions to RRSPs, child care expenses).
#
# ### Step 10: Lifestyle and Wellness
# 12. **Address lifestyle concerns.**
#     - Increase physical activity to more than once a week.
#     - Integrate wellness activities as a family to combat sedentary habits.
#
# ### Step 11: Review and Monitor
# 13. **Regularly review and adjust the financial plan.**
#     - Schedule annual reviews to track progress, reassess goals, and make necessary adjustments.
#
# ### Summary of Recommendations:
# 1. **Develop a monthly budget** to track and manage income and expenses.
# 2. **Prioritize debt repayment** by paying off the car loan and considering mortgage refinancing.
# 3. **Secure adequate life and disability insurance** to protect family income and financial stability.
# 4. **Establish an emergency fund** of 3-6 months' worth of living expenses.
# 5. **Implement a medium-risk, diversified investment strategy** using RRSPs, TFSAs, and other investment vehicles.
# 6. **Contribute to RESPs** for children’s education and take advantage of government grants.
# 7. **Project retirement needs and adjust contributions** to retirement accounts.
# 8. **Optimize tax strategies** to minimize tax liabilities.
# 9. **Incorporate regular physical activity** to improve overall wellness.
# 10. **Schedule annual reviews** to ensure the financial plan remains aligned with their evolving goals and circumstances.
#
# This plan balances current financial stability with future security, ensuring John and his family are well-prepared for various life stages.
#
# --------------------------------------------------------------------------------
# Mentor (to User):
#
# Excellent approach, let's delve into how we can ensure John Smith receives comprehensive financial guidance while also integrating ABC Bank's products to meet these needs. Here’s a step-by-step instructional model for you to follow, and considerations for handling various clients effectively:
#
# ### Step 1: Understand Financial Goals and Priorities
# - **Short-term:** Emergency fund, vacations
#   - **ABC Recommendation:** Suggest opening a high-yield Savings Account with ABC Bank to accumulate these funds efficiently.
#
# - **Medium-term:** College funds for daughters
#   - **ABC Recommendation:** Discuss setting up Registered Education Savings Plans (RESPs) through ABC Bank, which offers potential government grants (Canada Education Savings Grant).
#
# - **Long-term:** Retirement planning, paying off the mortgage
#   - **ABC Recommendation:** Recommend ABC Bank's RRSPs (Registered Retirement Savings Plan) and offer mortgage refinancing options that might reduce their interest rate or lower their monthly payments.
#
# ### Step 2: Budgeting and Cash Flow Management
# 1. **Analyze Current Income and Expenses**
#    - Help the client create a detailed budget by segmenting fixed and discretionary expenses.
#
# 2. **Create a Monthly Budget**
#    - **ABC Recommendation:** Use ABC Bank's Budgeting Tools available in their online banking platform to categorize expenses and track spending.
#
# ### Step 3: Debt Management
# 1. **Review Current Debts**
#    - Prioritize and strategize to pay off debts efficiently.
#    - **ABC Recommendation:** Offer competitive refinancing solutions for their $800,000 mortgage through ABC Bank and perhaps look into consolidating their car loan if it offers better terms.
#
# ### Step 4: Insurance Coverage
# 1. **Evaluate Insurance Needs**
#    - **Life Insurance:** Suggest ABC Bank’s term life insurance policies to cover income replacement and mortgage repayment.
#    - **Disability Insurance:** Propose ABC Bank’s disability insurance options to protect income in case of unforeseen circumstances.
#    - **Health Insurance:** Ensure their health insurance is adequate, considering supplementary policies if necessary.
#
# ### Step 5: Emergency Fund
# 1. **Build an Emergency Fund**
#    - **ABC Recommendation:** Open a high-yield Savings Account with ABC Bank for their emergency fund to ensure liquidity and growth of the funds.
#
# ### Step 6: Investment Strategies
# 1. **Set Up an Investment Plan Based on Their Medium-Risk Profile**
#    - **Retirement Accounts:** Suggest ABC Bank's RRSPs and employer-sponsored plans for tax-deferred growth.
#    - **Tax-Free Savings Account (TFSA):** Recommend using TFSAs available through ABC Bank for tax-efficient growth.
#    - **Diversified Portfolio:** Guide them towards mutual funds, stocks, and bonds offered by ABC Bank that match their risk profile and time horizon.
#
# ### Step 7: Education Planning
# 1. **Start Saving for Daughter's Education**
#    - **ABC Recommendation:** Utilize ABC Bank’s RESP accounts to benefit from government grants and tax-deferred growth.
#
# ### Step 8: Retirement Planning
# 1. **Project Retirement Needs**
#    - Work with them to estimate retirement needs based on their retirement age and lifestyle.
#    - **ABC Recommendation:** Increase contributions to ABC Bank’s RRSPs to ensure adequate retirement savings.
#
# ### Step 9: Tax Planning
# 1. **Optimize Tax Strategies**
#    - **ABC Recommendation:** Discuss tax-efficient investment options and strategies tailored by ABC Bank’s financial advisors to reduce tax liabilities.
#
# ### Step 10: Lifestyle and Wellness
# 1. **Address Lifestyle Concerns**
#    - Encourage the integration of wellness activities and healthier lifestyles, which is essential for long-term health.
#
# ### Step 11: Review and Monitor
# 1. **Regularly Review and Adjust the Financial Plan**
#    - **ABC Recommendation:** Schedule annual or semi-annual reviews using ABC Bank’s financial planning services to ensure their plan adapts to their evolving needs and life circumstances.
#
# ### Summary of Recommendations for the Mentee:
# 1. **Develop a comprehensive, client-centric approach:** Ensure you have an in-depth understanding of clients' goals and tailor your advice accordingly.
# 2. **Propose relevant ABC Bank products:** Always align your recommendations with the products and solutions offered by your institution.
# 3. **Prioritize debt management and risk protection:** Focus on strategies that help clients manage debts efficiently and protect their income and assets.
# 4. **Leverage technology and tools:** Use bank tools to help clients track their progress and manage their finances easily.
# 5. **Maintain regular communication:** Schedule frequent reviews to stay updated on clients’ changing circumstances and financial needs.
#
# By adhering to this structured process and considering these guiding principles, you'll be able to deliver effective financial advice and foster deeper, more trusting client relationships.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# In the form of attribute:value print out the profile for John Smith and his family
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# ```plaintext
# Client: John Smith
# Sex: Male
# Age: 40 years old
# Home: Unionville, Ontario, Canada
# Family:
#   - Spouse: Jane Smith, 39 years old
#   - Children:
#       - Meaghan Smith, 12 years old
#       - Rachael Smith, 10 years old
#   - Pet: Patches, 10-year-old black and white cat, considered a family member
# Occupation: Teacher
# Income:
#   - John Smith: $100,000 per year
#   - Jane Smith: $80,000 per year
# Current Assets:
#   - Savings Account: $100,000
#   - GIC from Inheritance: $2,000,000
# Current Liabilities:
#   - Car Loan: $20,000
#   - Mortgage: $800,000 on a $1,000,000 home
# Annual Expenses:
#   - Private School: $40,000 per student per year ($80,000 total per year for two children)
#   - Utilities and Home Taxes: $24,000 per year
# Health Coverage:
#   - Employer-provided health coverage
#   - Provincial OHIP plan
# Risk Profile: Medium
# Lifestyle:
#   - Preference for expensive cars and luxury lifestyle
#   - Plans for 2 family vacations per year
#   - Generally sedentary lifestyle, exercises once a week
# Existing Investments:
#   - No investments in RRSP or RESP
#   - Work pension as a teacher
# Financial Goals:
#   - Interested in purchasing a house in Markham
# Other Needs:
#   - Inclusion of pet care for Patches in financial planning
# ```
#
# --------------------------------------------------------------------------------

# %%
# Final Questions for Bloom's Taxonomy Evaluation

text = "What do you remember about John Smith?"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

text = "Can you describe his financial profile?"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

text = "How would uou describe his financial situation?"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

text = "What recommendations would you make about his financial situation"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

text = "What additional information would you like to have about John Smith and what additional insights could you provide?"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)

text = "Create a year by year plan for the next 3 years for John Smith and his family to improve their financial health and meet their financial goals"
user.initiate_chat(role_teachable_agent, message=text, max_turns=1, clear_history=True)
# Out:
# User (to WealthAdvisor):
#
# What do you remember about John Smith?
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# Great, let’s consolidate the financial and personal profile of John Smith further for a more comprehensive understanding. Here’s a combined overview based on your inputs:
#
# ### Financial Profile
# 1. **Income:**
#    - John Smith: $100,000 per year
#    - Jane Smith: $80,000 per year
#
# 2. **Expenses:**
#    - Private School: $40,000 per student per year ($80,000 annually for two children)
#    - Utilities and Home Taxes: $24,000 per year
#    - Car Loan: $20,000 remaining
#    - Lifestyle: Preferences for expensive cars and luxury items (assume high discretionary spending)
#    - Family Vacations: Planned for 2 vacations per year (est. $10,000-$15,000 annually)
#
# 3. **Savings and Investments:**
#    - Bank Savings Account: $100,000
#    - GIC from Inheritance: $2,000,000
#    - No current investments in RRSP or RESP
#
# 4. **Liabilities:**
#    - Mortgage: $800,000 on a $1,000,000 home
#    - Car loan: $20,000
#
# 5. **Assets:**
#    - Home: $1,000,000
#    - Savings: $100,000
#    - GIC: $2,000,000
#
# ### Personal Profile
# - **Age and Family:**
#   - John Smith: 40 years old
#   - Jane Smith: 39 years old
#   - Children: Meaghan (12) and Rachael (10)
#   - Pet: Patches, a 10-year-old black and white cat
#
# - **Occupation:**
#   - John Smith: Teacher
#   - Pension: Yes (work pension as a teacher)
#   - Health Coverage: Employer-provided and OHIP plan
#
# - **Lifestyle and Risk Profile:**
#   - Medium risk tolerance
#   - Enjoys luxury lifestyle which may be beyond current financial means
#   - Limited physical activity, mostly sedentary
#
# ### Additional Insights Needed:
# 1. **Family's Long-Term Goals:**
#    - Retirement age and desired lifestyle post-retirement
#    - Future education plans for Meaghan and Rachael (University, other private schooling, etc.)
#    - Long-term housing plans (considering buying a house in Markham)
#
# 2. **Jane Smith’s Financial Details:**
#    - Pension availability
#    - Health coverage details
#    - Additional savings/investments
#
# 3. **Additional Insurance Needs:**
#    - Lack of life insurance for both John and Jane
#    - Need for disability insurance
#    - Pet insurance for Patches
#
# 4. **RRSP and RESP Contributions:**
#    - Plans for starting retirement savings (RRSP) and educational savings (RESP)
#
# 5. **Health and Personal Planning:**
#    - Increase in physical activity to reduce health risks associated with sedentary work
#    - Financial planning for potential higher healthcare costs in the future due to current lifestyle
#
# 6. **Market Analysis for Markham:**
#    - Future housing market trends
#    - Cost implications of moving and maintaining a second home or transitioning to a new one
#
# ### Additional Data That Would Be Useful:
# 1. **Detailed Budget Breakdown:**
#    - Detailed current monthly and annual expenses
#    - Discretionary vs. non-discretionary spending
#
# 2. **Jane’s Financial Details:**
#    - Specifics about Jane’s pension and health coverage
#    - Any existing debts not mentioned
#
# 3. **Tax Considerations:**
#    - Current tax bracket and strategies to reduce taxable income
#    - Potential tax implications from the inheritance
#
# 4. **Investment Preferences:**
#    - John and Jane’s preferences for different types of investments (stocks, bonds, real estate, etc.)
#
# 5. **Estate Planning:**
#    - Current will and estate plans
#    - Plans for beneficiaries, including any provisions for Patches
#
# By collecting this additional data and insights, I can tailor more specific and practical financial recommendations that align with John and his family’s unique needs and goals. Let me know if there’s a specific area you’d like to dive deeper into next!
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# Can you describe his financial profile?
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# Given the detailed information about John Smith's financial profile, here’s a comprehensive overview:
#
# ### Financial Profile Summary:
#
# 1. **Income and Savings:**
#    - **Inheritance:** $2,000,000 in a GIC (Guaranteed Investment Certificate).
#    - **Savings Account:** $100,000 available in a bank savings account.
#    - **Pension:** Benefits from a work pension as a teacher.
#
# 2. **Expenses:**
#    - **Private School Tuition:** $40,000 per year, per child.
#    - **Annual Utilities and Property Taxes:** $24,000.
#    - **Luxury Lifestyle Costs:** High discretionary spending on expensive cars and other luxury items.
#
# 3. **Health Coverage:**
#    - **Employer-provided Health Benefits:** Comprehensive health coverage.
#    - **Provincial OHIP Plan:** Public health coverage.
#
# 4. **Investment Status:**
#    - **No Investments in RRSP or RESP:** Has not yet allocated funds to Registered Retirement Savings Plan or Registered Education Savings Plans.
#
# 5. **Family Considerations:**
#    - **Children:** Private school education incurs significant expenses.
#    - **Pet:** Patches, the 10-year-old cat, is considered a family member and may have associated care costs.
#
# ### Additional Insights Needed:
#
# To provide a more tailored and effective financial strategy for John and his family, the following additional information would be helpful:
#
# 1. **John’s Annual Income:**
#    - Current salary and any other sources of income.
#
# 2. **Future Financial Goals:**
#    - Specific short-term and long-term goals, such as vacation plans, children's college fund, retirement age, etc.
#
# 3. **Desired Lifestyle:**
#    - Spending habits and preferences, current debts (if any), and major upcoming expenses.
#
# 4. **Investment Preferences:**
#    - Risk tolerance and investment preferences (e.g., conservative, moderate, aggressive).
#
# 5. **Housing Market Considerations:**
#    - Detailed requirements for the house in Markham and budget allocation for purchasing real estate.
#
# 6. **Insurance Coverage:**
#    - Life insurance, property insurance, and any other relevant insurance policies.
#
# ### Additional Data for Recommendations:
#
# 1. **Detailed List of Current Debts:**
#    - Any outstanding loans or credit card debts.
#
# 2. **Current Portfolio Details:**
#    - Breakdown of the current assets and their allocation (if any exist outside of known savings and GIC).
#
# 3. **Estate Planning:**
#    - Any existing wills, trusts, or plans for inheritance distribution.
#
# 4. **Tax Information:**
#    - Current tax bracket and any tax considerations or liabilities.
#
# ### Recommendations:
#
# 1. **Budgeting and Expense Management:**
#    - Create a balanced budget factoring in educational expenses, utilities, lifestyle costs, and potential pet expenses.
#
# 2. **Investment in RRSP and RESP:**
#    - Start contributing to RRSP for tax-advantaged retirement savings and RESP for children's education to benefit from government grants.
#
# 3. **Real Estate Planning:**
#    - Provide a detailed analysis of the housing market in Markham, including future trends and affordability based on John’s financial situation.
#
# 4. **Diversified Investment Strategy:**
#    - Diversify investments beyond GICs to potentially include stocks, bonds, mutual funds, and real estate, aligned with John's risk tolerance.
#
# 5. **Luxury Spending Analysis:**
#    - Assessment of the sustainability of maintaining a luxury lifestyle, identifying necessary trade-offs or additional income sources if needed.
#
# 6. **Estate and Tax Planning:**
#    - Develop a comprehensive estate plan, including wills and possibly trusts, to ensure proper wealth transfer and minimize tax liabilities.
#
# By gathering the additional information and focusing on these recommendations, we can help John achieve his financial objectives while ensuring the financial well-being of his family and maintaining a balanced lifestyle.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# How would uou describe his financial situation?
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# Based on the collected facts and insights, here is a description of John Smith’s financial situation:
#
# ### Current Financial Profile
# 1. **Income and Employment:**
#    - John is a teacher with a steady income and has a work pension as a part of his employment benefits.
#    - Comprehensive health coverage through his employer and the provincial OHIP plan.
#
# 2. **Assets:**
#    - $2,000,000 inherited from his father, currently placed in a Guaranteed Investment Certificate (GIC) in the bank.
#    - $100,000 in a bank savings account.
#
# 3. **Expenses:**
#    - High educational expenses due to children's private school costs totaling $40,000 per student per year.
#    - Utilities and home taxes amounting to $24,000 annually.
#    - John has a preference for expensive cars and a luxury lifestyle that might strain his financial resources.
#
# 4. **Investments:**
#    - No investments in RRSP (Registered Retirement Savings Plan) or RESP (Registered Education Savings Plan) to date.
#
# 5. **Future Plans:**
#    - Considering purchasing a house in Markham and interested in detailed information about the housing market there.
#    - The family cat, Patches, who is considered a member of the family, might have specific needs that should be factored into financial planning.
#
# ### Additional Insights Needed
# To develop a comprehensive financial plan for John, additional information that would be useful includes:
# 1. **Income Breakdown:**
#    - Detailed monthly or annual income, including any supplementary income from side jobs or investments.
#
# 2. **Expenses Detail:**
#    - A detailed breakdown of all monthly and annual expenses, including miscellaneous and non-essential expenditures.
#
# 3. **Financial Goals:**
#    - Short-term and long-term financial goals, such as retirement age, desired retirement lifestyle, children's education funding, and major upcoming expenses.
#
# 4. **Debt Situation:**
#    - Complete information on any existing debts (credit cards, personal loans, mortgages, etc.) including interest rates and repayment terms.
#
# 5. **Risk Tolerance:**
#    - Understanding John's risk tolerance to recommend appropriate investment strategies.
#
# 6. **Housing Market in Markham:**
#    - Detailed analysis and trends in the Markham housing market, including average home prices, future growth projections, and other factors that might influence his decision.
#
# 7. **Expenses for Patches:**
#    - Estimation of annual expenses related to the care of the family cat, Patches, including veterinary care, food, and other necessities.
#
# ### Recommendations Based on Current Insights
# Here are some preliminary recommendations for John based on the current insights:
#
# 1. **Investment Diversification:**
#    - Consider diversifying the inherited $2,000,000 currently in a GIC. Since GICs offer low returns, exploring options in equities, bonds, and mutual funds could provide better returns while managing risk.
#
# 2. **RRSP and RESP:**
#    - Begin contributions to an RRSP to take advantage of tax deferrals and potentially reduce current tax liabilities.
#    - Set up and contribute to RESPs for his children’s education to benefit from government grants and tax-deferred growth.
#
# 3. **Budgeting and Expense Management:**
#    - Develop a detailed budgeting plan to manage high lifestyle expenses.
#    - Focus on reducing non-essential expenses to ensure savings for essential and long-term financial goals.
#
# 4. **Housing Market Analysis:**
#    - Conduct a thorough analysis of the housing market in Markham to help John make an informed decision regarding his potential house purchase.
#
# 5. **Retirement Planning:**
#    - Create a retirement savings plan that aligns with John's desired retirement age, factoring in his work pension and additional savings needed to maintain his luxury lifestyle.
#
# 6. **Health and Pet Care:**
#    - Ensure a fund allocation for potential health-related expenses not covered by his employer or provincial health plan.
#    - Account for an annual budget for Patches' care to ensure the cat's needs are sustainably met.
#
# Gathering the additional information mentioned will help in tailoring a more accurate and personalized financial strategy for John.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# What recommendations would you make about his financial situation
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# Based on the comprehensive financial profile and the additional insights provided, here are some personalized recommendations for John Smith's financial situation:
#
# ### Income and Expenses Analysis
# 1. **Income Breakdown**:
#    - John Smith: $100,000 per year
#    - Jane Smith: $80,000 per year
#    - Total Household Income: $180,000 per year
#
# 2. **Annual Expenses**:
#    - Private School Tuition: $80,000 per year ($40,000 per child x 2)
#    - Utilities & Home Taxes: $24,000 per year
#    - Mortgage Payments: Assuming an average 3% interest rate on the $800,000 mortgage over 25 years, approximately $45,000 per year
#    - Car Loan Payments: Depending on interest, let's assume $5,000 per year
#    - Family Vacations: Estimating $10,000 per year
#    - Miscellaneous Expenses (lifestyle, maintenance, groceries, etc.): $50,000 per year
#
#    **Total Annual Expenses: $214,000 per year** (excluding any potential additional costs related to Patches, the family cat).
#
# ### Investment and Savings Recommendations
# 1. **Emergency Fund**:
#    - Retain at least 6-12 months of living expenses in easily accessible savings (around $107,000 - $214,000).
#
# 2. **Invest the Inheritance**:
#    - Move the $2,000,000 from the GIC into a diversified portfolio to achieve higher returns. Consider a mix of stocks (60%), bonds (30%), and alternative investments (10%) aligned with John's medium risk profile.
#
# 3. **Registered Accounts**:
#    - **RRSP**: Start contributing to an RRSP to benefit from tax advantages. Maximize annual contribution limits.
#    - **RESP**: Open an RESP for the children's education costs to benefit from the CESG (Canada Education Savings Grant) and tax-deferred growth.
#
# 4. **Pension and Retirement Planning**:
#    - Assess the adequacy of John’s teacher pension for future retirement needs. Supplement with RRSP contributions and consider Tax-Free Savings Accounts (TFSAs) for additional tax-advantaged growth.
#
# ### Specific Needs for Patches the Cat
# 1. **Pet Insurance**:
#    - Consider purchasing pet insurance for Patches to cover potential health care costs as she ages.
#
# 2. **Annual Budget for Patches**:
#    - Allocate approximately $1,000-$2,000 per year for food, vet visits, and other expenses.
#
# ### Housing Market in Markham
# 1. **Market Analysis**:
#    - Research the Markham housing market trends. Evaluate average property prices, market conditions (buyer’s/seller’s market), and potential return on investment.
#    - Consider working with a real estate agent to identify suitable properties within John's budget and lifestyle needs.
#
# ### Lifestyle Adjustments
# 1. **Managing Luxury Expenses**:
#    - Evaluate the overall spending on luxury items. Recommend setting a reasonable budget that fits within the family’s financial constraints.
#
# 2. **Life Insurance**:
#    - Obtain life insurance to ensure the family’s financial security in case of unexpected events.
#
# ### Tax Planning
# 1. **Tax Efficiency**:
#    - Utilize tax-efficient investment strategies to minimize tax liabilities. Consult with a tax advisor to optimize the family’s tax situation.
#
# ### Health & Wellness
# 1. **Lifestyle Changes**:
#    - Increase physical activity and reduce sedentary behavior for long-term health benefits. This could indirectly lead to reduced health expenses over time.
#
# ### Final Remarks
# Considering the current financial landscape and the family's needs, these tailored recommendations aim to ensure financial stability, growth, and security for John Smith and his family, including their pet Patches. Regular reviews and adjustments should be made as circumstances evolve.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# What additional information would you like to have about John Smith and what additional insights could you provide?
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# To provide comprehensive financial advice for John Smith, I would need additional information in several areas to tailor my recommendations more effectively. Here’s what additional information would be beneficial and what other insights could be useful for John and his family:
#
# ### Additional Information Needed:
#
# 1. **Detailed Financial Goals:**
#    - Retirement age for John and Jane.
#    - Desired retirement lifestyle and estimated annual expenses.
#    - Future financial goals: Further education for children, major purchases (e.g., vacation home), philanthropic endeavors, etc.
#
# 2. **Health and Insurance:**
#    - Detailed health insurance coverage and any gaps that might need to be addressed.
#    - Coverage details and cost for pet insurance for Patches to ensure his needs are met.
#    - Interest in additional life insurance or critical illness insurance policies.
#
# 3. **Investment Preferences:**
#    - John's risk tolerance more precisely for different types of investment (equities, bonds, real estate).
#    - Interest in ethical or socially responsible investments.
#
# 4. **Mortgage and Debt Details:**
#    - Terms and interest rates on the $800,000 mortgage.
#    - Any other debt (credit card, personal loans) aside from the $20,000 car loan.
#    - Existing credit score information.
#
# 5. **Expenses and Liabilities:**
#    - Break down of monthly spending (utilities, groceries, leisure, etc.).
#    - Estimated future costs for private schooling, including potential tuition increases.
#
# 6. **Additional Assets:**
#    - Details of any other assets (real estate, vehicles, collectibles).
#    - John's pension plan details to understand future income stream from it.
#
# ### Additional Insights:
#
# 1. **Tax Strategy:**
#    - Tax implications of the inherited $2,000,000.
#    - Potential benefits and strategies for contributing to RRSPs and RESPs.
#    - Explore tax-efficient investment options.
#    - Utilize the income-splitting strategy if applicable.
#
# 2. **Investment Portfolio Diversification:**
#    - Recommendations for diversifying the $2,000,000 currently in a GIC.
#    - Explore investments in the stock market, bonds, real estate, or mutual funds.
#    - Introduce the concept of a diversified portfolio to balance risk and return.
#
# 3. **Estate Planning:**
#    - Importance of having a will and keeping it updated.
#    - Setting up a trust for the children’s education and other long-term goals.
#    - Consideration of estate taxes and how to mitigate them.
#
# 4. **Real Estate Market in Markham:**
#    - Current trends and forecast of the housing market in Markham.
#    - Potential impact of buying a home on overall financial health.
#    - Evaluation of whether renting out the current home or selling it would be more beneficial when purchasing a new home.
#
# 5. **Lifestyle and Budget Management:**
#    - Develop a realistic budget that allows for luxury expenditures while maintaining financial health.
#    - Financial impacts of owning and maintaining expensive cars.
#    - Strategies for reducing unnecessary expenses and reallocating funds towards savings and investments.
#
# 6. **Health and Well-being:**
#    - Encouragement to increase frequency of exercise to improve overall health, which can impact financial health in terms of medical expenses and insurance premiums.
#
# ### Additional Data Useful for Recommendations:
#
# 1. **Historical Financial Statements:**
#    - Detailed income and expenditure history to spot trends and patterns.
#
# 2. **Market Research Data:**
#    - Comprehensive market analysis reports tailored to John's investment interests.
#
# 3. **Legal Documents:**
#    - Current wills, trusts, or any pre-existing financial documents related to estate planning.
#
# 4. **Professional Evaluations:**
#    - Detailed appraisals of any high-value assets (real estate, vintage cars, etc.).
#
# With this information, I would be able to provide John Smith with customized, strategic financial advice aimed at securing his family's future and achieving their financial goals.
#
# --------------------------------------------------------------------------------
# User (to WealthAdvisor):
#
# Create a year by year plan for the next 3 years for John Smith and his family to improve their financial health and meet their financial goals
#
# --------------------------------------------------------------------------------
# WealthAdvisor (to User):
#
# Here's a detailed year-by-year financial plan for John Smith and his family for the next three years, considering their financial profile, goals, and needs.
#
# ### Year 1
#
# #### Income and Investments
# 1. **Income Allocation**
#    - John's salary: $100,000
#    - Jane's salary: $80,000
#    - Total Income: $180,000
#
# 2. **Investment in RRSP and RESP**
#    - RRSP Contributions: Aim to contribute $18,000 (10% of gross income)
#    - RESP Contributions for both daughters: $5,000 per child = $10,000
#
# 3. **Review GICs**
#    - Analyze the $2,000,000 in GICs and evaluate alternatives like diversified investment portfolios to achieve higher returns while managing risk.
#
# #### Expenses
# 1. **Private School Costs**
#    - $80,000 for both daughters
#
# 2. **Utilities and Home Taxes**
#    - $24,000
#
# 3. **Car Loan**
#    - Aim to pay off $20,000 car loan within this year to reduce debt.
#
# 4. **Family Vacations**
#    - Budget $15,000 for two family vacations.
#
# 5. **Pet Care**
#    - Allocate $1,200 for Patches' food, health check-ups, and grooming.
#
# 6. **Luxury Allowance**
#    - Set aside $10,000 for discretionary spending on luxury items.
#
# 7. **Emergency Fund**
#    - Keep the existing $100,000 as an emergency fund.
#
# ### Year 2
#
# #### Income and Investments
# 1. **Income Allocation**
#    - John's updated salary (assuming a modest raise): $105,000
#    - Jane's updated salary: $84,000
#    - Total Income: $189,000
#
# 2. **Investment in RRSP and RESP**
#    - Increase RRSP contributions to $20,000
#    - Continue RESP contributions: $10,000 (for both daughters)
#
# 3. **Diversified Portfolio**
#    - Move a portion of the GIC fund into a diversified portfolio: $500,000 in stocks, bonds, and real estate.
#
# #### Expenses
# 1. **Private School Costs**
#    - $80,000
#
# 2. **Utilities and Home Taxes**
#    - $24,000
#
# 3. **Car Purchase**
#    - Consider buying a new car if necessary, with a budget of $40,000.
#
# 4. **Family Vacations**
#    - Budget $15,000 for two family vacations.
#
# 5. **Pet Care**
#    - Continue to allocate $1,200 for Patches.
#
# 6. **Expense Management**
#    - Review and cut unnecessary luxury expenses, maintaining a $5,000 allowance.
#
# 7. **Emergency Fund**
#    - Maintain an emergency fund of $100,000.
#
# ### Year 3
#
# #### Income and Investments
# 1. **Income Allocation**
#    - John's updated salary: $110,000
#    - Jane's updated salary: $88,000
#    - Total Income: $198,000
#
# 2. **Investment in RRSP and RESP**
#    - Increase RRSP contributions to $22,000
#    - Continue RESP contributions: $10,000 (for both daughters)
#
# 3. **Rebalance Portfolio**
#    - Review and rebalance the diversified portfolio to optimize for risk and return.
#
# 4. **Additional Investments**
#    - Consider investing in real estate in Markham if the market is favorable, take $500,000 from the GIC for a down payment.
#
# #### Expenses
# 1. **Private School Costs**
#    - $80,000
#
# 2. **Utilities and Home Taxes**
#    - $24,000
#
# 3. **Luxury lifestyle Management**
#    - Maintain a $5,000 luxury allowance and evaluate need-based luxury purchases.
#
# 4. **Family Vacations**
#    - Budget $15,000 for two family vacations.
#
# 5. **Pet Care**
#    - $1,200 for Patches.
#
# 6. **Housing Market Evaluation**
#    - Provide regular updates on the Markham housing market and assist in making informed decisions if purchasing a home.
#
# 7. **Emergency Fund**
#    - Maintain an emergency fund of $100,000.
#
# ### Additional Steps
# 1. **Life Insurance Coverage**
#    - Obtain life insurance for both John and Jane to protect the family’s financial future in case of any unforeseen events.
#    - Estimated Premium: $2,000 annually.
#
# 2. **Health and Wellness**
#    - Invest in a family health and wellness program to reduce sedentary lifestyle; allocate $1,200 yearly for gym memberships or wellness activities.
#
# 3. **Estate Planning**
#    - Develop a comprehensive estate plan, including a will and potential trust arrangements.
#
# #### Summary
#
# This three-year plan focuses on balancing John’s current expenses, debt management, strategic investment, and saving for the family's future needs, all while considering the financial well-being of the family cat, Patches. Regular evaluations and adjustments will be vital to ensure the family stays on track with their financial goals.
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': 'Create a year by year plan for the next 3 years for John Smith and his family to improve their financial health and meet their financial goals', 'role': 'assistant'}, {'content': "Here's a detailed year-by-year financial plan for John Smith and his family for the next three years, considering their financial profile, goals, and needs.\n\n### Year 1\n\n#### Income and Investments\n1. **Income Allocation**\n   - John's salary: $100,000\n   - Jane's salary: $80,000\n   - Total Income: $180,000\n\n2. **Investment in RRSP and RESP**\n   - RRSP Contributions: Aim to contribute $18,000 (10% of gross income)\n   - RESP Contributions for both daughters: $5,000 per child = $10,000\n\n3. **Review GICs**\n   - Analyze the $2,000,000 in GICs and evaluate alternatives like diversified investment portfolios to achieve higher returns while managing risk.\n\n#### Expenses\n1. **Private School Costs**\n   - $80,000 for both daughters\n\n2. **Utilities and Home Taxes**\n   - $24,000\n\n3. **Car Loan**\n   - Aim to pay off $20,000 car loan within this year to reduce debt.\n\n4. **Family Vacations**\n   - Budget $15,000 for two family vacations.\n\n5. **Pet Care**\n   - Allocate $1,200 for Patches' food, health check-ups, and grooming.\n\n6. **Luxury Allowance**\n   - Set aside $10,000 for discretionary spending on luxury items.\n\n7. **Emergency Fund**\n   - Keep the existing $100,000 as an emergency fund.\n\n### Year 2\n\n#### Income and Investments\n1. **Income Allocation**\n   - John's updated salary (assuming a modest raise): $105,000\n   - Jane's updated salary: $84,000\n   - Total Income: $189,000\n\n2. **Investment in RRSP and RESP**\n   - Increase RRSP contributions to $20,000\n   - Continue RESP contributions: $10,000 (for both daughters)\n\n3. **Diversified Portfolio**\n   - Move a portion of the GIC fund into a diversified portfolio: $500,000 in stocks, bonds, and real estate. \n\n#### Expenses\n1. **Private School Costs**\n   - $80,000\n\n2. **Utilities and Home Taxes**\n   - $24,000\n\n3. **Car Purchase**\n   - Consider buying a new car if necessary, with a budget of $40,000.\n\n4. **Family Vacations**\n   - Budget $15,000 for two family vacations.\n\n5. **Pet Care**\n   - Continue to allocate $1,200 for Patches.\n\n6. **Expense Management**\n   - Review and cut unnecessary luxury expenses, maintaining a $5,000 allowance.\n\n7. **Emergency Fund**\n   - Maintain an emergency fund of $100,000.\n\n### Year 3\n\n#### Income and Investments\n1. **Income Allocation**\n   - John's updated salary: $110,000\n   - Jane's updated salary: $88,000\n   - Total Income: $198,000\n\n2. **Investment in RRSP and RESP**\n   - Increase RRSP contributions to $22,000\n   - Continue RESP contributions: $10,000 (for both daughters)\n   \n3. **Rebalance Portfolio**\n   - Review and rebalance the diversified portfolio to optimize for risk and return.\n\n4. **Additional Investments**\n   - Consider investing in real estate in Markham if the market is favorable, take $500,000 from the GIC for a down payment.\n\n#### Expenses\n1. **Private School Costs**\n   - $80,000\n\n2. **Utilities and Home Taxes**\n   - $24,000\n\n3. **Luxury lifestyle Management**\n   - Maintain a $5,000 luxury allowance and evaluate need-based luxury purchases.\n\n4. **Family Vacations**\n   - Budget $15,000 for two family vacations.\n\n5. **Pet Care**\n   - $1,200 for Patches.\n\n6. **Housing Market Evaluation**\n   - Provide regular updates on the Markham housing market and assist in making informed decisions if purchasing a home.\n\n7. **Emergency Fund**\n   - Maintain an emergency fund of $100,000.\n\n### Additional Steps\n1. **Life Insurance Coverage**\n   - Obtain life insurance for both John and Jane to protect the family’s financial future in case of any unforeseen events.\n   - Estimated Premium: $2,000 annually.\n\n2. **Health and Wellness**\n   - Invest in a family health and wellness program to reduce sedentary lifestyle; allo ...
